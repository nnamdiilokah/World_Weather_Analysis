# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000,high=90.000,size=2000)
lngs = np.random.uniform(low=-180.000,high=180.000,size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 755

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import nnam

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + nnam

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]      
        city_weather_description = city_weather["weather"][0]["description"]   
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kassala
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | victoria
# Processing Record 4 of Set 1 | burica
# City not found. Skipping...
# Processing Record 5 of Set 1 | aksarka
# Processing Record 6 of Set 1 | mogadishu
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | katsuura
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | porto murtinho
# Processing Record 11 of Set 1 | tuktoyaktuk
# Processing Record 12 of Set 1 | naze
# Processing Record 13 of Set 1 | meulaboh
# Processing Record 14 of Set 1 | castro
# Processing Record 15 of Set 1 | lagoa
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | lebu
# Processing Record 19 of Set 1 | thompson
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | east london
# Processing Record 22 of Set 1 | flinders
# Processing Record 23 of Set 1 | severo-kurilsk
# Processing Record 24 of Set 1 | tiarei
# Processing Record 25 of Set 1 | villanueva de la serena
# Processing Record 26 of Set 1 | saint george
# Processing Record 27 of Set 1 | vestmannaeyjar
# Processing Record 28 of Set 1 | dudinka
# Processing Record 29 of Set 1 | salalah
# Processing Record 30 of Set 1 | kavieng
# Processing Record 31 of Set 1 | puerto ayora
# Processing Record 32 of Set 1 | bluff
# Processing Record 33 of Set 1 | yellowknife
# Processing Record 34 of Set 1 | churapcha
# Processing Record 35 of Set 1 | qaanaaq
# Processing Record 36 of Set 1 | hobyo
# Processing Record 37 of Set 1 | olinda
# Processing Record 38 of Set 1 | hermanus
# Processing Record 39 of Set 1 | xining
# Processing Record 40 of Set 1 | kieta
# Processing Record 41 of Set 1 | faanui
# Processing Record 42 of Set 1 | hobart
# Processing Record 43 of Set 1 | freeport
# Processing Record 44 of Set 1 | wanning
# Processing Record 45 of Set 1 | nouakchott
# Processing Record 46 of Set 1 | mahebourg
# Processing Record 47 of Set 1 | butaritari
# Processing Record 48 of Set 1 | chumphon
# Processing Record 49 of Set 1 | namibe
# Processing Record 50 of Set 1 | chuy
# Processing Record 1 of Set 2 | cockburn town
# Processing Record 2 of Set 2 | fortuna
# Processing Record 3 of Set 2 | bredasdorp
# Processing Record 4 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 2 | jamestown
# Processing Record 6 of Set 2 | sola
# Processing Record 7 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 2 | cape town
# Processing Record 9 of Set 2 | kosa
# Processing Record 10 of Set 2 | provideniya
# Processing Record 11 of Set 2 | atuona
# Processing Record 12 of Set 2 | alofi
# Processing Record 13 of Set 2 | saint-philippe
# Processing Record 14 of Set 2 | sur
# Processing Record 15 of Set 2 | geraldton
# Processing Record 16 of Set 2 | asau
# Processing Record 17 of Set 2 | clyde river
# Processing Record 18 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 2 | siniscola
# Processing Record 20 of Set 2 | atlantic beach
# Processing Record 21 of Set 2 | vila franca do campo
# Processing Record 22 of Set 2 | mascota
# Processing Record 23 of Set 2 | mabaruma
# Processing Record 24 of Set 2 | carnarvon
# Processing Record 25 of Set 2 | moa
# Processing Record 26 of Set 2 | necochea
# Processing Record 27 of Set 2 | elkton
# Processing Record 28 of Set 2 | chokurdakh
# Processing Record 29 of Set 2 | raudeberg
# Processing Record 30 of Set 2 | dikson
# Processing Record 31 of Set 2 | alice springs
# Processing Record 32 of Set 2 | airai
# Processing Record 33 of Set 2 | teknaf
# Processing Record 34 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 2 | cherskiy
# Processing Record 36 of Set 2 | port alfred
# Processing Record 37 of Set 2 | vardo
# Processing Record 38 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 2 | cidreira
# Processing Record 40 of Set 2 | walvis bay
# Processing Record 41 of Set 2 | bratsk
# Processing Record 42 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 2 | tuatapere
# Processing Record 44 of Set 2 | kapaa
# Processing Record 45 of Set 2 | new norfolk
# Processing Record 46 of Set 2 | cabo san lucas
# Processing Record 47 of Set 2 | pangnirtung
# Processing Record 48 of Set 2 | kruisfontein
# Processing Record 49 of Set 2 | teya
# Processing Record 50 of Set 2 | sisimiut
# Processing Record 1 of Set 3 | nalut
# Processing Record 2 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 3 | iwanai
# Processing Record 4 of Set 3 | jiaocheng
# Processing Record 5 of Set 3 | longyearbyen
# Processing Record 6 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 3 | leningradskiy
# Processing Record 8 of Set 3 | mandera
# Processing Record 9 of Set 3 | sao raimundo nonato
# Processing Record 10 of Set 3 | codrington
# Processing Record 11 of Set 3 | sampit
# Processing Record 12 of Set 3 | comodoro rivadavia
# Processing Record 13 of Set 3 | iqaluit
# Processing Record 14 of Set 3 | bambous virieux
# Processing Record 15 of Set 3 | nara
# Processing Record 16 of Set 3 | prince george
# Processing Record 17 of Set 3 | farsund
# Processing Record 18 of Set 3 | corinto
# Processing Record 19 of Set 3 | hampton
# Processing Record 20 of Set 3 | kayerkan
# Processing Record 21 of Set 3 | fairbanks
# Processing Record 22 of Set 3 | huarmey
# Processing Record 23 of Set 3 | guajara-mirim
# City not found. Skipping...
# Processing Record 24 of Set 3 | kaitangata
# Processing Record 25 of Set 3 | dwarka
# Processing Record 26 of Set 3 | abu zabad
# Processing Record 27 of Set 3 | talnakh
# Processing Record 28 of Set 3 | oranjestad
# Processing Record 29 of Set 3 | ribeira grande
# Processing Record 30 of Set 3 | wonthaggi
# Processing Record 31 of Set 3 | ilulissat
# Processing Record 32 of Set 3 | san quintin
# Processing Record 33 of Set 3 | avarua
# Processing Record 34 of Set 3 | berlevag
# Processing Record 35 of Set 3 | hilo
# Processing Record 36 of Set 3 | madang
# Processing Record 37 of Set 3 | acas
# Processing Record 38 of Set 3 | bengkulu
# Processing Record 39 of Set 3 | beloha
# Processing Record 40 of Set 3 | paraiso
# Processing Record 41 of Set 3 | jiaohe
# Processing Record 42 of Set 3 | homnabad
# Processing Record 43 of Set 3 | nikolskoye
# Processing Record 44 of Set 3 | lamar
# Processing Record 45 of Set 3 | bury saint edmunds
# City not found. Skipping...
# Processing Record 46 of Set 3 | warrnambool
# Processing Record 47 of Set 3 | khatanga
# Processing Record 48 of Set 3 | mar del plata
# Processing Record 49 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 3 | san fernando
# Processing Record 1 of Set 4 | shelton
# Processing Record 2 of Set 4 | saldanha
# Processing Record 3 of Set 4 | port blair
# Processing Record 4 of Set 4 | port elizabeth
# Processing Record 5 of Set 4 | kudahuvadhoo
# Processing Record 6 of Set 4 | udomlya
# Processing Record 7 of Set 4 | itarema
# Processing Record 8 of Set 4 | nemuro
# Processing Record 9 of Set 4 | nieuw amsterdam
# Processing Record 10 of Set 4 | upernavik
# Processing Record 11 of Set 4 | kloulklubed
# Processing Record 12 of Set 4 | cabedelo
# Processing Record 13 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 14 of Set 4 | araripina
# Processing Record 15 of Set 4 | skalistyy
# City not found. Skipping...
# Processing Record 16 of Set 4 | sorland
# Processing Record 17 of Set 4 | vaini
# Processing Record 18 of Set 4 | adrar
# Processing Record 19 of Set 4 | hambantota
# Processing Record 20 of Set 4 | oyama
# Processing Record 21 of Set 4 | calhoun
# Processing Record 22 of Set 4 | ostrovnoy
# Processing Record 23 of Set 4 | gull lake
# Processing Record 24 of Set 4 | merauke
# Processing Record 25 of Set 4 | hasaki
# Processing Record 26 of Set 4 | nanortalik
# Processing Record 27 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 28 of Set 4 | komarichi
# Processing Record 29 of Set 4 | mareeba
# Processing Record 30 of Set 4 | saskylakh
# Processing Record 31 of Set 4 | hithadhoo
# Processing Record 32 of Set 4 | san patricio
# Processing Record 33 of Set 4 | luderitz
# Processing Record 34 of Set 4 | bonthe
# Processing Record 35 of Set 4 | pedini
# Processing Record 36 of Set 4 | nome
# Processing Record 37 of Set 4 | chapais
# Processing Record 38 of Set 4 | ust-tsilma
# Processing Record 39 of Set 4 | tungor
# Processing Record 40 of Set 4 | fort nelson
# Processing Record 41 of Set 4 | fukue
# Processing Record 42 of Set 4 | tabas
# Processing Record 43 of Set 4 | tubuala
# Processing Record 44 of Set 4 | torbay
# Processing Record 45 of Set 4 | otukpo
# Processing Record 46 of Set 4 | houma
# Processing Record 47 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 4 | port hardy
# Processing Record 49 of Set 4 | srem
# Processing Record 50 of Set 4 | sitka
# Processing Record 1 of Set 5 | arraial do cabo
# Processing Record 2 of Set 5 | nuuk
# Processing Record 3 of Set 5 | comarapa
# Processing Record 4 of Set 5 | sinkat
# City not found. Skipping...
# Processing Record 5 of Set 5 | kargasok
# Processing Record 6 of Set 5 | lompoc
# Processing Record 7 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 5 | umm kaddadah
# Processing Record 9 of Set 5 | norman wells
# Processing Record 10 of Set 5 | soyo
# Processing Record 11 of Set 5 | port macquarie
# Processing Record 12 of Set 5 | kodiak
# Processing Record 13 of Set 5 | bethel
# Processing Record 14 of Set 5 | aykhal
# Processing Record 15 of Set 5 | bereda
# Processing Record 16 of Set 5 | rincon
# Processing Record 17 of Set 5 | jiuquan
# Processing Record 18 of Set 5 | westport
# Processing Record 19 of Set 5 | axim
# Processing Record 20 of Set 5 | murmashi
# Processing Record 21 of Set 5 | thiruvananthapuram
# Processing Record 22 of Set 5 | zhelyabovka
# Processing Record 23 of Set 5 | komsomolskiy
# Processing Record 24 of Set 5 | sokol
# Processing Record 25 of Set 5 | zabaykalsk
# Processing Record 26 of Set 5 | rio grande
# Processing Record 27 of Set 5 | pachino
# Processing Record 28 of Set 5 | brainerd
# Processing Record 29 of Set 5 | barrow
# Processing Record 30 of Set 5 | baykit
# Processing Record 31 of Set 5 | quelimane
# Processing Record 32 of Set 5 | zaozerne
# Processing Record 33 of Set 5 | bathsheba
# Processing Record 34 of Set 5 | quatre cocos
# Processing Record 35 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 37 of Set 5 | shelby
# Processing Record 38 of Set 5 | jaru
# Processing Record 39 of Set 5 | narrabri
# Processing Record 40 of Set 5 | barinas
# Processing Record 41 of Set 5 | jabiru
# City not found. Skipping...
# Processing Record 42 of Set 5 | sapa
# Processing Record 43 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 44 of Set 5 | aklavik
# Processing Record 45 of Set 5 | sebinkarahisar
# Processing Record 46 of Set 5 | cherdyn
# Processing Record 47 of Set 5 | point fortin
# Processing Record 48 of Set 5 | bilgi
# Processing Record 49 of Set 5 | magog
# Processing Record 50 of Set 5 | ngunguru
# Processing Record 1 of Set 6 | la ronge
# Processing Record 2 of Set 6 | shahumyan
# Processing Record 3 of Set 6 | shache
# Processing Record 4 of Set 6 | sao joao da barra
# Processing Record 5 of Set 6 | fez
# Processing Record 6 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 6 | taoudenni
# Processing Record 8 of Set 6 | tasiilaq
# Processing Record 9 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 10 of Set 6 | kpandae
# Processing Record 11 of Set 6 | vallenar
# Processing Record 12 of Set 6 | firsanovka
# Processing Record 13 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 6 | isangel
# Processing Record 15 of Set 6 | mandalgovi
# Processing Record 16 of Set 6 | newport
# Processing Record 17 of Set 6 | truth or consequences
# Processing Record 18 of Set 6 | rovaniemi
# Processing Record 19 of Set 6 | viru
# Processing Record 20 of Set 6 | zhigansk
# Processing Record 21 of Set 6 | gizo
# Processing Record 22 of Set 6 | reitz
# Processing Record 23 of Set 6 | la cruz
# Processing Record 24 of Set 6 | szczytno
# Processing Record 25 of Set 6 | katherine
# Processing Record 26 of Set 6 | sawakin
# Processing Record 27 of Set 6 | mailsi
# Processing Record 28 of Set 6 | ponta do sol
# Processing Record 29 of Set 6 | oksfjord
# Processing Record 30 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 31 of Set 6 | hamilton
# Processing Record 32 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 6 | roebourne
# Processing Record 34 of Set 6 | pandamatenga
# Processing Record 35 of Set 6 | bath
# Processing Record 36 of Set 6 | tiksi
# Processing Record 37 of Set 6 | ust-nera
# Processing Record 38 of Set 6 | beneditinos
# Processing Record 39 of Set 6 | canutama
# Processing Record 40 of Set 6 | batemans bay
# Processing Record 41 of Set 6 | siguatepeque
# Processing Record 42 of Set 6 | ixtapa
# Processing Record 43 of Set 6 | minas
# Processing Record 44 of Set 6 | monrovia
# Processing Record 45 of Set 6 | bonfim
# Processing Record 46 of Set 6 | pereslavl-zalesskiy
# Processing Record 47 of Set 6 | chapada dos guimaraes
# Processing Record 48 of Set 6 | cayenne
# Processing Record 49 of Set 6 | broome
# Processing Record 50 of Set 6 | souillac
# Processing Record 1 of Set 7 | baijiantan
# Processing Record 2 of Set 7 | itacare
# Processing Record 3 of Set 7 | esperance
# Processing Record 4 of Set 7 | tucumcari
# Processing Record 5 of Set 7 | nouadhibou
# Processing Record 6 of Set 7 | georgetown
# Processing Record 7 of Set 7 | kulhudhuffushi
# Processing Record 8 of Set 7 | pedernales
# Processing Record 9 of Set 7 | teguise
# Processing Record 10 of Set 7 | tessalit
# Processing Record 11 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 12 of Set 7 | eureka
# Processing Record 13 of Set 7 | grenfell
# Processing Record 14 of Set 7 | jasper
# Processing Record 15 of Set 7 | mayo
# Processing Record 16 of Set 7 | eden
# Processing Record 17 of Set 7 | pevek
# Processing Record 18 of Set 7 | kongoussi
# Processing Record 19 of Set 7 | tucuman
# Processing Record 20 of Set 7 | marawi
# Processing Record 21 of Set 7 | crab hill
# City not found. Skipping...
# Processing Record 22 of Set 7 | coquimbo
# Processing Record 23 of Set 7 | atocha
# Processing Record 24 of Set 7 | san cristobal
# Processing Record 25 of Set 7 | los llanos de aridane
# Processing Record 26 of Set 7 | the valley
# Processing Record 27 of Set 7 | awbari
# Processing Record 28 of Set 7 | hauterive
# Processing Record 29 of Set 7 | san lorenzo
# Processing Record 30 of Set 7 | nantucket
# Processing Record 31 of Set 7 | nonthaburi
# Processing Record 32 of Set 7 | tiznit
# Processing Record 33 of Set 7 | mozarlandia
# Processing Record 34 of Set 7 | chibuto
# Processing Record 35 of Set 7 | rosetown
# Processing Record 36 of Set 7 | kimbe
# Processing Record 37 of Set 7 | gamba
# Processing Record 38 of Set 7 | tura
# Processing Record 39 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 40 of Set 7 | zhuhai
# Processing Record 41 of Set 7 | olga
# Processing Record 42 of Set 7 | penzance
# Processing Record 43 of Set 7 | jumla
# Processing Record 44 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 7 | keuruu
# Processing Record 46 of Set 7 | malakal
# Processing Record 47 of Set 7 | vostok
# Processing Record 48 of Set 7 | dawei
# Processing Record 49 of Set 7 | velingara
# Processing Record 50 of Set 7 | yomitan
# City not found. Skipping...
# Processing Record 1 of Set 8 | luis correia
# Processing Record 2 of Set 8 | karimganj
# Processing Record 3 of Set 8 | grootfontein
# Processing Record 4 of Set 8 | bandundu
# Processing Record 5 of Set 8 | havoysund
# Processing Record 6 of Set 8 | yumen
# Processing Record 7 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 8 of Set 8 | dhemaji
# Processing Record 9 of Set 8 | camacha
# Processing Record 10 of Set 8 | haines junction
# Processing Record 11 of Set 8 | komsomolets
# Processing Record 12 of Set 8 | boyolangu
# Processing Record 13 of Set 8 | pisco
# Processing Record 14 of Set 8 | zarechnyy
# Processing Record 15 of Set 8 | vila velha
# Processing Record 16 of Set 8 | port lincoln
# Processing Record 17 of Set 8 | oktyabrskiy
# Processing Record 18 of Set 8 | turukhansk
# Processing Record 19 of Set 8 | sao filipe
# Processing Record 20 of Set 8 | waddan
# Processing Record 21 of Set 8 | santa maria
# Processing Record 22 of Set 8 | buariki
# City not found. Skipping...
# Processing Record 23 of Set 8 | atar
# Processing Record 24 of Set 8 | dzilam gonzalez
# Processing Record 25 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 8 | santa rosa
# Processing Record 27 of Set 8 | gorontalo
# Processing Record 28 of Set 8 | lakselv
# Processing Record 29 of Set 8 | yatou
# Processing Record 30 of Set 8 | candido mendes
# Processing Record 31 of Set 8 | kendari
# Processing Record 32 of Set 8 | harper
# Processing Record 33 of Set 8 | gejiu
# Processing Record 34 of Set 8 | mount gambier
# Processing Record 35 of Set 8 | grand gaube
# Processing Record 36 of Set 8 | butterworth
# Processing Record 37 of Set 8 | suruc
# Processing Record 38 of Set 8 | lata
# Processing Record 39 of Set 8 | padang
# Processing Record 40 of Set 8 | pitimbu
# Processing Record 41 of Set 8 | narsaq
# Processing Record 42 of Set 8 | chernyshevsk
# Processing Record 43 of Set 8 | vao
# Processing Record 44 of Set 8 | denpasar
# Processing Record 45 of Set 8 | arlit
# Processing Record 46 of Set 8 | xilagani
# Processing Record 47 of Set 8 | amurzet
# Processing Record 48 of Set 8 | terrasini
# Processing Record 49 of Set 8 | liwale
# Processing Record 50 of Set 8 | ulaanbaatar
# Processing Record 1 of Set 9 | bafra
# Processing Record 2 of Set 9 | mariental
# Processing Record 3 of Set 9 | dinsor
# City not found. Skipping...
# Processing Record 4 of Set 9 | athgarh
# City not found. Skipping...
# Processing Record 5 of Set 9 | damaturu
# Processing Record 6 of Set 9 | voh
# Processing Record 7 of Set 9 | bolkhov
# Processing Record 8 of Set 9 | mbekenyera
# Processing Record 9 of Set 9 | trelew
# Processing Record 10 of Set 9 | svetlogorsk
# Processing Record 11 of Set 9 | paragominas
# Processing Record 12 of Set 9 | pierre
# Processing Record 13 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 14 of Set 9 | lepe
# Processing Record 15 of Set 9 | darvari
# Processing Record 16 of Set 9 | bandarbeyla
# Processing Record 17 of Set 9 | kahului
# Processing Record 18 of Set 9 | ust-koksa
# Processing Record 19 of Set 9 | northam
# Processing Record 20 of Set 9 | pocone
# Processing Record 21 of Set 9 | samsun
# Processing Record 22 of Set 9 | paratinga
# Processing Record 23 of Set 9 | lovozero
# Processing Record 24 of Set 9 | chuhar kana
# Processing Record 25 of Set 9 | ranong
# Processing Record 26 of Set 9 | hudson bay
# Processing Record 27 of Set 9 | honiara
# Processing Record 28 of Set 9 | galle
# Processing Record 29 of Set 9 | smithers
# Processing Record 30 of Set 9 | sasebo
# Processing Record 31 of Set 9 | yacuiba
# Processing Record 32 of Set 9 | guerrero negro
# Processing Record 33 of Set 9 | dingle
# Processing Record 34 of Set 9 | moron
# Processing Record 35 of Set 9 | carutapera
# Processing Record 36 of Set 9 | uyo
# Processing Record 37 of Set 9 | aswan
# Processing Record 38 of Set 9 | tateyama
# Processing Record 39 of Set 9 | portland
# Processing Record 40 of Set 9 | roald
# Processing Record 41 of Set 9 | klaksvik
# Processing Record 42 of Set 9 | male
# Processing Record 43 of Set 9 | konza
# Processing Record 44 of Set 9 | waingapu
# Processing Record 45 of Set 9 | dongsheng
# Processing Record 46 of Set 9 | camocim
# Processing Record 47 of Set 9 | puerto vallarta
# Processing Record 48 of Set 9 | conceicao do araguaia
# Processing Record 49 of Set 9 | constitucion
# Processing Record 50 of Set 9 | lasa
# Processing Record 1 of Set 10 | paamiut
# Processing Record 2 of Set 10 | samarai
# Processing Record 3 of Set 10 | tabou
# Processing Record 4 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 10 | iquique
# Processing Record 6 of Set 10 | hervey bay
# Processing Record 7 of Set 10 | carballo
# Processing Record 8 of Set 10 | itaituba
# Processing Record 9 of Set 10 | maragogi
# Processing Record 10 of Set 10 | manyana
# Processing Record 11 of Set 10 | araouane
# Processing Record 12 of Set 10 | kysyl-syr
# Processing Record 13 of Set 10 | zhezkazgan
# Processing Record 14 of Set 10 | vegueta
# Processing Record 15 of Set 10 | kuusamo
# Processing Record 16 of Set 10 | campbell river
# Processing Record 17 of Set 10 | saint-pierre
# Processing Record 18 of Set 10 | kamaishi
# Processing Record 19 of Set 10 | brooks
# Processing Record 20 of Set 10 | kavaratti
# Processing Record 21 of Set 10 | eregli
# Processing Record 22 of Set 10 | asayita
# City not found. Skipping...
# Processing Record 23 of Set 10 | te anau
# Processing Record 24 of Set 10 | grindavik
# Processing Record 25 of Set 10 | pangai
# Processing Record 26 of Set 10 | koungou
# Processing Record 27 of Set 10 | villa carlos paz
# Processing Record 28 of Set 10 | estelle
# Processing Record 29 of Set 10 | stoyba
# City not found. Skipping...
# Processing Record 30 of Set 10 | laguna
# Processing Record 31 of Set 10 | manado
# Processing Record 32 of Set 10 | trairi
# Processing Record 33 of Set 10 | sangin
# Processing Record 34 of Set 10 | chebenki
# Processing Record 35 of Set 10 | berthierville
# Processing Record 36 of Set 10 | san juan
# Processing Record 37 of Set 10 | atikokan
# Processing Record 38 of Set 10 | linqiong
# Processing Record 39 of Set 10 | vigrestad
# Processing Record 40 of Set 10 | japura
# Processing Record 41 of Set 10 | bonavista
# Processing Record 42 of Set 10 | manbij
# Processing Record 43 of Set 10 | eyl
# Processing Record 44 of Set 10 | spencer
# Processing Record 45 of Set 10 | bilma
# Processing Record 46 of Set 10 | helong
# Processing Record 47 of Set 10 | chuncheng
# Processing Record 48 of Set 10 | bacabal
# Processing Record 49 of Set 10 | kirakira
# Processing Record 50 of Set 10 | aldan
# Processing Record 1 of Set 11 | vanavara
# Processing Record 2 of Set 11 | benguela
# Processing Record 3 of Set 11 | kuching
# Processing Record 4 of Set 11 | acapulco
# Processing Record 5 of Set 11 | birjand
# Processing Record 6 of Set 11 | baykalsk
# Processing Record 7 of Set 11 | santa cruz
# Processing Record 8 of Set 11 | najran
# Processing Record 9 of Set 11 | susehri
# Processing Record 10 of Set 11 | bira
# Processing Record 11 of Set 11 | ouro preto do oeste
# Processing Record 12 of Set 11 | anadyr
# Processing Record 13 of Set 11 | lodja
# Processing Record 14 of Set 11 | elizabeth city
# Processing Record 15 of Set 11 | owando
# Processing Record 16 of Set 11 | samarkand
# Processing Record 17 of Set 11 | mecca
# Processing Record 18 of Set 11 | lahad datu
# Processing Record 19 of Set 11 | hastings
# Processing Record 20 of Set 11 | bosaso
# Processing Record 21 of Set 11 | san carlos
# Processing Record 22 of Set 11 | kununurra
# Processing Record 23 of Set 11 | krasnogorskoye
# Processing Record 24 of Set 11 | west wendover
# Processing Record 25 of Set 11 | bacuit
# City not found. Skipping...
# Processing Record 26 of Set 11 | calama
# Processing Record 27 of Set 11 | atambua
# Processing Record 28 of Set 11 | arman
# Processing Record 29 of Set 11 | mount isa
# Processing Record 30 of Set 11 | kautokeino
# Processing Record 31 of Set 11 | duncan
# Processing Record 32 of Set 11 | lucapa
# Processing Record 33 of Set 11 | suhl
# Processing Record 34 of Set 11 | diglur
# Processing Record 35 of Set 11 | aquiraz
# Processing Record 36 of Set 11 | uwayl
# City not found. Skipping...
# Processing Record 37 of Set 11 | mishkino
# Processing Record 38 of Set 11 | kaeo
# Processing Record 39 of Set 11 | arroyo
# Processing Record 40 of Set 11 | sorong
# Processing Record 41 of Set 11 | ahuimanu
# Processing Record 42 of Set 11 | rosehearty
# Processing Record 43 of Set 11 | ternate
# Processing Record 44 of Set 11 | san jose
# Processing Record 45 of Set 11 | seminole
# Processing Record 46 of Set 11 | manggar
# Processing Record 47 of Set 11 | qandala
# Processing Record 48 of Set 11 | ancud
# Processing Record 49 of Set 11 | mwinilunga
# Processing Record 50 of Set 11 | ninh binh
# Processing Record 1 of Set 12 | kindu
# Processing Record 2 of Set 12 | wasco
# Processing Record 3 of Set 12 | khandyga
# Processing Record 4 of Set 12 | urbano santos
# Processing Record 5 of Set 12 | saint-georges
# Processing Record 6 of Set 12 | zambezi
# Processing Record 7 of Set 12 | sencha
# Processing Record 8 of Set 12 | lixourion
# Processing Record 9 of Set 12 | puerto escondido
# Processing Record 10 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 11 of Set 12 | goya
# Processing Record 12 of Set 12 | tadepallegudem
# Processing Record 13 of Set 12 | iskateley
# Processing Record 14 of Set 12 | seoul
# Processing Record 15 of Set 12 | beyneu
# Processing Record 16 of Set 12 | williamsport
# Processing Record 17 of Set 12 | husavik
# Processing Record 18 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 19 of Set 12 | yulara
# Processing Record 20 of Set 12 | hattiesburg
# Processing Record 21 of Set 12 | hofn
# Processing Record 22 of Set 12 | craig
# Processing Record 23 of Set 12 | romny
# Processing Record 24 of Set 12 | donskoye
# Processing Record 25 of Set 12 | villa rica
# Processing Record 26 of Set 12 | tromso
# Processing Record 27 of Set 12 | inuvik
# Processing Record 28 of Set 12 | champerico
# Processing Record 29 of Set 12 | gazojak
# Processing Record 30 of Set 12 | pavlodar
# Processing Record 31 of Set 12 | fairview
# Processing Record 32 of Set 12 | dindori
# Processing Record 33 of Set 12 | adre
# Processing Record 34 of Set 12 | urulga
# City not found. Skipping...
# Processing Record 35 of Set 12 | luwuk
# Processing Record 36 of Set 12 | sioux lookout
# Processing Record 37 of Set 12 | avera
# Processing Record 38 of Set 12 | taplanszentkereszt
# Processing Record 39 of Set 12 | chegdomyn
# Processing Record 40 of Set 12 | kupang
# Processing Record 41 of Set 12 | sisian
# Processing Record 42 of Set 12 | bhopal
# Processing Record 43 of Set 12 | xuanwu
# Processing Record 44 of Set 12 | saint anthony
# Processing Record 45 of Set 12 | peterhead
# Processing Record 46 of Set 12 | sao felix do xingu
# Processing Record 47 of Set 12 | launceston
# Processing Record 48 of Set 12 | fethiye
# Processing Record 49 of Set 12 | hirara
# Processing Record 50 of Set 12 | kamenka
# Processing Record 1 of Set 13 | dunedin
# Processing Record 2 of Set 13 | neuquen
# Processing Record 3 of Set 13 | illapel
# Processing Record 4 of Set 13 | nador
# Processing Record 5 of Set 13 | vila do maio
# Processing Record 6 of Set 13 | half moon bay
# Processing Record 7 of Set 13 | novosergiyevka
# Processing Record 8 of Set 13 | mormugao
# Processing Record 9 of Set 13 | tabulbah
# City not found. Skipping...
# Processing Record 10 of Set 13 | lyndon
# Processing Record 11 of Set 13 | maniitsoq
# Processing Record 12 of Set 13 | gumdag
# Processing Record 13 of Set 13 | medak
# Processing Record 14 of Set 13 | kilindoni
# Processing Record 15 of Set 13 | labuhan
# Processing Record 16 of Set 13 | bartica
# Processing Record 17 of Set 13 | touros
# Processing Record 18 of Set 13 | pasighat
# Processing Record 19 of Set 13 | sistranda
# Processing Record 20 of Set 13 | abbeville
# Processing Record 21 of Set 13 | port-gentil
# Processing Record 22 of Set 13 | lazarev
# Processing Record 23 of Set 13 | novoagansk
# Processing Record 24 of Set 13 | les trois-ilets
# Processing Record 25 of Set 13 | kuah
# Processing Record 26 of Set 13 | rawson
# Processing Record 27 of Set 13 | edwardsville
# Processing Record 28 of Set 13 | egvekinot
# Processing Record 29 of Set 13 | canoinhas
# Processing Record 30 of Set 13 | athabasca
# Processing Record 31 of Set 13 | ormara
# Processing Record 32 of Set 13 | jiwani
# Processing Record 33 of Set 13 | stornoway
# Processing Record 34 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 13 | pascagoula
# Processing Record 36 of Set 13 | buba
# Processing Record 37 of Set 13 | brae
# Processing Record 38 of Set 13 | luxor
# Processing Record 39 of Set 13 | korla
# Processing Record 40 of Set 13 | benghazi
# Processing Record 41 of Set 13 | tabuk
# Processing Record 42 of Set 13 | buraydah
# Processing Record 43 of Set 13 | mitsamiouli
# Processing Record 44 of Set 13 | college
# Processing Record 45 of Set 13 | tuy hoa
# Processing Record 46 of Set 13 | mercedes
# Processing Record 47 of Set 13 | ganserndorf
# Processing Record 48 of Set 13 | areni
# Processing Record 49 of Set 13 | coruripe
# Processing Record 50 of Set 13 | la palma
# Processing Record 1 of Set 14 | zaraza
# Processing Record 2 of Set 14 | kibala
# Processing Record 3 of Set 14 | havelock
# Processing Record 4 of Set 14 | kismayo
# Processing Record 5 of Set 14 | yerbogachen
# Processing Record 6 of Set 14 | djougou
# Processing Record 7 of Set 14 | hunza
# City not found. Skipping...
# Processing Record 8 of Set 14 | mega
# Processing Record 9 of Set 14 | terneuzen
# Processing Record 10 of Set 14 | puerto guzman
# Processing Record 11 of Set 14 | nueva loja
# Processing Record 12 of Set 14 | olavarria
# Processing Record 13 of Set 14 | abasolo
# Processing Record 14 of Set 14 | nhulunbuy
# Processing Record 15 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 14 | inverell
# Processing Record 17 of Set 14 | karratha
# Processing Record 18 of Set 14 | merano
# Processing Record 19 of Set 14 | tautira
# Processing Record 20 of Set 14 | saint andrews
# Processing Record 21 of Set 14 | praya
# Processing Record 22 of Set 14 | merritt island
# Processing Record 23 of Set 14 | ribeira brava
# Processing Record 24 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 25 of Set 14 | caxito
# Processing Record 26 of Set 14 | lorengau
# Processing Record 27 of Set 14 | nurobod
# Processing Record 28 of Set 14 | sibirtsevo
# City not found. Skipping...
# Processing Record 29 of Set 14 | micheweni
# Processing Record 30 of Set 14 | dickinson
# Processing Record 31 of Set 14 | buenos aires
# Processing Record 32 of Set 14 | yian
# City not found. Skipping...
# Processing Record 33 of Set 14 | chicama
# Processing Record 34 of Set 14 | virginia beach
# Processing Record 35 of Set 14 | san vicente
# Processing Record 36 of Set 14 | nelson bay
# Processing Record 37 of Set 14 | kourou
# Processing Record 38 of Set 14 | prieska
# Processing Record 39 of Set 14 | potgietersrus
# City not found. Skipping...
# Processing Record 40 of Set 14 | port hedland
# Processing Record 41 of Set 14 | hay river
# Processing Record 42 of Set 14 | himora
# City not found. Skipping...
# Processing Record 43 of Set 14 | santa cruz de la palma
# Processing Record 44 of Set 14 | mergui
# City not found. Skipping...
# Processing Record 45 of Set 14 | pervomayskoye
# Processing Record 46 of Set 14 | guayaramerin
# Processing Record 47 of Set 14 | ulladulla
# Processing Record 48 of Set 14 | nizwa
# Processing Record 49 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 50 of Set 14 | kyshtovka
# Processing Record 1 of Set 15 | kachikau
# City not found. Skipping...
# Processing Record 2 of Set 15 | otjiwarongo
# Processing Record 3 of Set 15 | mugur-aksy
# Processing Record 4 of Set 15 | macamic
# Processing Record 5 of Set 15 | banepa
# Processing Record 6 of Set 15 | huadian
# Processing Record 7 of Set 15 | san juan bautista
# Processing Record 8 of Set 15 | cabanas
# Processing Record 9 of Set 15 | namatanai
# Processing Record 10 of Set 15 | dicabisagan
# Processing Record 11 of Set 15 | khandbari
# Processing Record 12 of Set 15 | buon me thuot
# City not found. Skipping...
# Processing Record 13 of Set 15 | okhotsk
# Processing Record 14 of Set 15 | ginir
# Processing Record 15 of Set 15 | daru
# Processing Record 16 of Set 15 | dubbo
# Processing Record 17 of Set 15 | kalmunai
# Processing Record 18 of Set 15 | olden
# Processing Record 19 of Set 15 | ferme-neuve
# Processing Record 20 of Set 15 | popondetta
# Processing Record 21 of Set 15 | ayagoz
# Processing Record 22 of Set 15 | erbaa
# Processing Record 23 of Set 15 | salinopolis
# Processing Record 24 of Set 15 | faya
# Processing Record 25 of Set 15 | berdyuzhye
# City not found. Skipping...
# Processing Record 26 of Set 15 | tilichiki
# Processing Record 27 of Set 15 | borca
# Processing Record 28 of Set 15 | pankrushikha
# Processing Record 29 of Set 15 | pemba
# Processing Record 30 of Set 15 | tamandare
# Processing Record 31 of Set 15 | am timan
# Processing Record 32 of Set 15 | lanivtsi
# Processing Record 33 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 34 of Set 15 | susanville
# Processing Record 35 of Set 15 | prenzlau
# Processing Record 36 of Set 15 | malanje
# Processing Record 37 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 38 of Set 15 | calvinia
# Processing Record 39 of Set 15 | pemangkat
# Processing Record 40 of Set 15 | channel-port aux basques
# Processing Record 41 of Set 15 | excelsior springs
# Processing Record 42 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 43 of Set 15 | tatarsk
# Processing Record 44 of Set 15 | caravelas
# Processing Record 45 of Set 15 | vung tau
# Processing Record 46 of Set 15 | bud
# Processing Record 47 of Set 15 | varhaug
# Processing Record 48 of Set 15 | nicoya
# Processing Record 49 of Set 15 | sayyan
# Processing Record 50 of Set 15 | maputo
# Processing Record 1 of Set 16 | mataram
# Processing Record 2 of Set 16 | rockhampton
# Processing Record 3 of Set 16 | namwala
# Processing Record 4 of Set 16 | baiyin
# Processing Record 5 of Set 16 | neryungri
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 693

# %%
city_weather = requests.get(city_url).json()
city_weather
# Out:
# {'coord': {'lon': 124.6491, 'lat': 56.6709},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 38.84,
#   'feels_like': 32.18,
#   'temp_min': 38.84,
#   'temp_max': 38.84,
#   'pressure': 1014,
#   'humidity': 71,
#   'sea_level': 1014,
#   'grnd_level': 928},
#  'visibility': 10000,
#  'wind': {'speed': 10.07, 'deg': 164, 'gust': 15.9},
#  'clouds': {'all': 99},
#  'dt': 1664601566,
#  'sys': {'country': 'RU', 'sunrise': 1664574213, 'sunset': 1664615926},
#  'timezone': 32400,
#  'id': 2019309,
#  'name': 'Neryungri',
#  'cod': 200}

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Kassala  15.4510   36.4000     79.63        64          34
# 1         Mataura -46.1927  168.8643     51.48        46           0
# 2        Victoria  22.2855  114.1577     89.65        77          33
# 3         Aksarka  66.5606   67.7975     31.73        58          38
# 4       Mogadishu   2.0371   45.3438     78.96        76          14
# 5    Punta Arenas -53.1500  -70.9167     44.11        65          99
# 6        Katsuura  35.1333  140.3000     76.64        65           0
# 7         Ushuaia -54.8000  -68.3000     37.11        95          99
# 8  Porto Murtinho -21.6989  -57.8825     66.16        95          67
# 9     Tuktoyaktuk  69.4541 -133.0374     34.34        86         100
#
#    Wind Speed Country Current Description
# 0       11.27      SD    scattered clouds
# 1        5.68      NZ           clear sky
# 2       11.99      HK    scattered clouds
# 3       14.72      RU    scattered clouds
# 4       15.79      SO          few clouds
# 5       20.74      CL     overcast clouds
# 6       16.84      JP           clear sky
# 7        8.08      AR     overcast clouds
# 8        2.66      BR       broken clouds
# 9       18.21      CA     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df= city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Kassala      SD  15.4510   36.4000     79.63        64          34
# 1         Mataura      NZ -46.1927  168.8643     51.48        46           0
# 2        Victoria      HK  22.2855  114.1577     89.65        77          33
# 3         Aksarka      RU  66.5606   67.7975     31.73        58          38
# 4       Mogadishu      SO   2.0371   45.3438     78.96        76          14
# 5    Punta Arenas      CL -53.1500  -70.9167     44.11        65          99
# 6        Katsuura      JP  35.1333  140.3000     76.64        65           0
# 7         Ushuaia      AR -54.8000  -68.3000     37.11        95          99
# 8  Porto Murtinho      BR -21.6989  -57.8825     66.16        95          67
# 9     Tuktoyaktuk      CA  69.4541 -133.0374     34.34        86         100
#
#    Wind Speed Current Description
# 0       11.27    scattered clouds
# 1        5.68           clear sky
# 2       11.99    scattered clouds
# 3       14.72    scattered clouds
# 4       15.79          few clouds
# 5       20.74     overcast clouds
# 6       16.84           clear sky
# 7        8.08     overcast clouds
# 8        2.66       broken clouds
# 9       18.21     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
