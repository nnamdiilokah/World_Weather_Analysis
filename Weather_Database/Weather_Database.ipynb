# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000,high=90.000,size=2000)
lngs = np.random.uniform(low=-180.000,high=180.000,size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 763

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import nnam

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + nnam

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]      
        city_weather_description = city_weather["weather"][0]["description"]   
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | taft
# Processing Record 3 of Set 1 | san patricio
# Processing Record 4 of Set 1 | mahebourg
# Processing Record 5 of Set 1 | saint george
# Processing Record 6 of Set 1 | khatanga
# Processing Record 7 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 1 | mount isa
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | verkhoturye
# Processing Record 12 of Set 1 | faanui
# Processing Record 13 of Set 1 | chapais
# Processing Record 14 of Set 1 | dabhoi
# Processing Record 15 of Set 1 | kavieng
# Processing Record 16 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 1 | esperance
# Processing Record 18 of Set 1 | ostrovnoy
# Processing Record 19 of Set 1 | yinchuan
# Processing Record 20 of Set 1 | chingirlau
# Processing Record 21 of Set 1 | avarua
# Processing Record 22 of Set 1 | korla
# Processing Record 23 of Set 1 | saskylakh
# Processing Record 24 of Set 1 | hilo
# Processing Record 25 of Set 1 | hobart
# Processing Record 26 of Set 1 | cidreira
# Processing Record 27 of Set 1 | carnarvon
# Processing Record 28 of Set 1 | marathon
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | saint-georges
# Processing Record 31 of Set 1 | srednekolymsk
# Processing Record 32 of Set 1 | mindelo
# Processing Record 33 of Set 1 | jamestown
# Processing Record 34 of Set 1 | sobolevo
# Processing Record 35 of Set 1 | kapaa
# Processing Record 36 of Set 1 | saint-marc-des-carrieres
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | grindavik
# Processing Record 39 of Set 1 | luderitz
# Processing Record 40 of Set 1 | easthampton
# Processing Record 41 of Set 1 | nerchinskiy zavod
# Processing Record 42 of Set 1 | garowe
# Processing Record 43 of Set 1 | burnie
# Processing Record 44 of Set 1 | rantepao
# Processing Record 45 of Set 1 | chuy
# Processing Record 46 of Set 1 | rikitea
# Processing Record 47 of Set 1 | iqaluit
# Processing Record 48 of Set 1 | hasaki
# Processing Record 49 of Set 1 | borogontsy
# Processing Record 50 of Set 1 | yantai
# Processing Record 1 of Set 2 | atar
# Processing Record 2 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 2 | ouro preto do oeste
# Processing Record 4 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 5 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 2 | constantine
# Processing Record 7 of Set 2 | bethel
# Processing Record 8 of Set 2 | tiznit
# Processing Record 9 of Set 2 | lasa
# Processing Record 10 of Set 2 | miri
# Processing Record 11 of Set 2 | sulecin
# Processing Record 12 of Set 2 | yaan
# Processing Record 13 of Set 2 | ponta do sol
# Processing Record 14 of Set 2 | hithadhoo
# Processing Record 15 of Set 2 | tuktoyaktuk
# Processing Record 16 of Set 2 | tarudant
# City not found. Skipping...
# Processing Record 17 of Set 2 | boa vista
# Processing Record 18 of Set 2 | butaritari
# Processing Record 19 of Set 2 | sidi ali
# Processing Record 20 of Set 2 | port alfred
# Processing Record 21 of Set 2 | cam ranh
# Processing Record 22 of Set 2 | cayenne
# Processing Record 23 of Set 2 | kavaratti
# Processing Record 24 of Set 2 | lagoa
# Processing Record 25 of Set 2 | beidao
# Processing Record 26 of Set 2 | mitu
# Processing Record 27 of Set 2 | nome
# Processing Record 28 of Set 2 | tiksi
# Processing Record 29 of Set 2 | jega
# Processing Record 30 of Set 2 | bengkulu
# Processing Record 31 of Set 2 | souillac
# Processing Record 32 of Set 2 | nichinan
# Processing Record 33 of Set 2 | torbay
# Processing Record 34 of Set 2 | badoc
# Processing Record 35 of Set 2 | kankon
# Processing Record 36 of Set 2 | dwarka
# Processing Record 37 of Set 2 | skjervoy
# Processing Record 38 of Set 2 | praia da vitoria
# Processing Record 39 of Set 2 | san cristobal
# Processing Record 40 of Set 2 | kahului
# Processing Record 41 of Set 2 | cape town
# Processing Record 42 of Set 2 | yulara
# Processing Record 43 of Set 2 | lata
# Processing Record 44 of Set 2 | ushuaia
# Processing Record 45 of Set 2 | salta
# Processing Record 46 of Set 2 | provideniya
# Processing Record 47 of Set 2 | chokurdakh
# Processing Record 48 of Set 2 | dikson
# Processing Record 49 of Set 2 | severo-kurilsk
# Processing Record 50 of Set 2 | tamworth
# Processing Record 1 of Set 3 | escanaba
# Processing Record 2 of Set 3 | tasiilaq
# Processing Record 3 of Set 3 | sinnamary
# Processing Record 4 of Set 3 | puerto ayora
# Processing Record 5 of Set 3 | sao joao da barra
# Processing Record 6 of Set 3 | deputatskiy
# Processing Record 7 of Set 3 | hermanus
# Processing Record 8 of Set 3 | cap malheureux
# Processing Record 9 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 3 | pevek
# Processing Record 11 of Set 3 | mayo
# Processing Record 12 of Set 3 | zaysan
# Processing Record 13 of Set 3 | ojinaga
# Processing Record 14 of Set 3 | norman wells
# Processing Record 15 of Set 3 | kitimat
# Processing Record 16 of Set 3 | jacareacanga
# Processing Record 17 of Set 3 | poum
# Processing Record 18 of Set 3 | katsuura
# Processing Record 19 of Set 3 | veracruz
# Processing Record 20 of Set 3 | sisimiut
# Processing Record 21 of Set 3 | pisco
# Processing Record 22 of Set 3 | moroni
# Processing Record 23 of Set 3 | new norfolk
# Processing Record 24 of Set 3 | upernavik
# Processing Record 25 of Set 3 | lebu
# Processing Record 26 of Set 3 | albany
# Processing Record 27 of Set 3 | san quintin
# Processing Record 28 of Set 3 | sitka
# Processing Record 29 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 30 of Set 3 | ribeira grande
# Processing Record 31 of Set 3 | narsaq
# Processing Record 32 of Set 3 | victoria
# Processing Record 33 of Set 3 | sandpoint
# Processing Record 34 of Set 3 | barrow
# Processing Record 35 of Set 3 | valdivia
# Processing Record 36 of Set 3 | daru
# Processing Record 37 of Set 3 | torquay
# Processing Record 38 of Set 3 | qaanaaq
# Processing Record 39 of Set 3 | berdigestyakh
# Processing Record 40 of Set 3 | fortuna
# Processing Record 41 of Set 3 | umm kaddadah
# Processing Record 42 of Set 3 | atuona
# Processing Record 43 of Set 3 | kaeo
# Processing Record 44 of Set 3 | bluff
# Processing Record 45 of Set 3 | mar del plata
# Processing Record 46 of Set 3 | severo-yeniseyskiy
# Processing Record 47 of Set 3 | aklavik
# Processing Record 48 of Set 3 | kieta
# Processing Record 49 of Set 3 | tessalit
# Processing Record 50 of Set 3 | mabaruma
# Processing Record 1 of Set 4 | nadym
# Processing Record 2 of Set 4 | constitucion
# Processing Record 3 of Set 4 | noyabrsk
# Processing Record 4 of Set 4 | sabha
# Processing Record 5 of Set 4 | necochea
# Processing Record 6 of Set 4 | saint-pierre
# Processing Record 7 of Set 4 | longyearbyen
# Processing Record 8 of Set 4 | thinadhoo
# Processing Record 9 of Set 4 | launceston
# Processing Record 10 of Set 4 | prado
# Processing Record 11 of Set 4 | arraial do cabo
# Processing Record 12 of Set 4 | senmonorom
# City not found. Skipping...
# Processing Record 13 of Set 4 | valparaiso
# Processing Record 14 of Set 4 | iberia
# Processing Record 15 of Set 4 | bengbu
# Processing Record 16 of Set 4 | darab
# Processing Record 17 of Set 4 | jumla
# Processing Record 18 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 4 | kruisfontein
# Processing Record 20 of Set 4 | buenos aires
# Processing Record 21 of Set 4 | cabo san lucas
# Processing Record 22 of Set 4 | bilibino
# Processing Record 23 of Set 4 | charters towers
# Processing Record 24 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 4 | atkinson
# Processing Record 26 of Set 4 | kabelvag
# Processing Record 27 of Set 4 | moron
# Processing Record 28 of Set 4 | zhangye
# Processing Record 29 of Set 4 | camargo
# Processing Record 30 of Set 4 | shu
# Processing Record 31 of Set 4 | bajil
# Processing Record 32 of Set 4 | kodiak
# Processing Record 33 of Set 4 | ust-ilimsk
# Processing Record 34 of Set 4 | nanortalik
# Processing Record 35 of Set 4 | bonavista
# Processing Record 36 of Set 4 | yavatmal
# Processing Record 37 of Set 4 | castro
# Processing Record 38 of Set 4 | limon
# Processing Record 39 of Set 4 | shamary
# Processing Record 40 of Set 4 | bolobo
# Processing Record 41 of Set 4 | sabzevar
# Processing Record 42 of Set 4 | soure
# Processing Record 43 of Set 4 | okato
# Processing Record 44 of Set 4 | potsdam
# Processing Record 45 of Set 4 | port elizabeth
# Processing Record 46 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 4 | kedrovyy
# Processing Record 48 of Set 4 | cobija
# Processing Record 49 of Set 4 | karaton
# Processing Record 50 of Set 4 | namatanai
# Processing Record 1 of Set 5 | nikolskoye
# Processing Record 2 of Set 5 | biloela
# Processing Record 3 of Set 5 | asau
# Processing Record 4 of Set 5 | markova
# Processing Record 5 of Set 5 | saquena
# Processing Record 6 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 5 | calama
# Processing Record 8 of Set 5 | ranong
# Processing Record 9 of Set 5 | hatton
# Processing Record 10 of Set 5 | chon daen
# Processing Record 11 of Set 5 | gulu
# Processing Record 12 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 5 | clyde river
# Processing Record 14 of Set 5 | ancud
# Processing Record 15 of Set 5 | mizdah
# Processing Record 16 of Set 5 | yellowknife
# Processing Record 17 of Set 5 | sept-iles
# Processing Record 18 of Set 5 | dodge city
# Processing Record 19 of Set 5 | ibra
# Processing Record 20 of Set 5 | leningradskiy
# Processing Record 21 of Set 5 | lodwar
# Processing Record 22 of Set 5 | ilulissat
# Processing Record 23 of Set 5 | ayacucho
# Processing Record 24 of Set 5 | georgetown
# Processing Record 25 of Set 5 | namibe
# Processing Record 26 of Set 5 | lohja
# Processing Record 27 of Set 5 | broome
# Processing Record 28 of Set 5 | griffith
# Processing Record 29 of Set 5 | kenai
# Processing Record 30 of Set 5 | montepuez
# Processing Record 31 of Set 5 | sola
# Processing Record 32 of Set 5 | faya
# Processing Record 33 of Set 5 | asfi
# Processing Record 34 of Set 5 | bardiyah
# Processing Record 35 of Set 5 | paamiut
# Processing Record 36 of Set 5 | barabai
# Processing Record 37 of Set 5 | porto novo
# Processing Record 38 of Set 5 | volksrust
# Processing Record 39 of Set 5 | pangnirtung
# Processing Record 40 of Set 5 | alice springs
# Processing Record 41 of Set 5 | biltine
# Processing Record 42 of Set 5 | hambantota
# Processing Record 43 of Set 5 | freeport
# Processing Record 44 of Set 5 | kankaanpaa
# Processing Record 45 of Set 5 | campoverde
# Processing Record 46 of Set 5 | springfield
# Processing Record 47 of Set 5 | saint-louis
# Processing Record 48 of Set 5 | inhumas
# Processing Record 49 of Set 5 | nuqui
# Processing Record 50 of Set 5 | mandalgovi
# Processing Record 1 of Set 6 | bilma
# Processing Record 2 of Set 6 | boqueirao
# Processing Record 3 of Set 6 | musiri
# Processing Record 4 of Set 6 | clinton
# Processing Record 5 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 6 of Set 6 | ixtapa
# Processing Record 7 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 6 | uirauna
# Processing Record 9 of Set 6 | yirol
# City not found. Skipping...
# Processing Record 10 of Set 6 | klamath falls
# Processing Record 11 of Set 6 | zherdevka
# Processing Record 12 of Set 6 | khandyga
# Processing Record 13 of Set 6 | gondanglegi
# Processing Record 14 of Set 6 | bend
# Processing Record 15 of Set 6 | taraz
# Processing Record 16 of Set 6 | puerto escondido
# Processing Record 17 of Set 6 | marzuq
# Processing Record 18 of Set 6 | acapulco
# Processing Record 19 of Set 6 | krasnoselkup
# Processing Record 20 of Set 6 | tingrela
# City not found. Skipping...
# Processing Record 21 of Set 6 | nouadhibou
# Processing Record 22 of Set 6 | lakatoro
# Processing Record 23 of Set 6 | elhovo
# Processing Record 24 of Set 6 | pacific grove
# Processing Record 25 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 26 of Set 6 | ambunti
# Processing Record 27 of Set 6 | tabou
# Processing Record 28 of Set 6 | beyneu
# Processing Record 29 of Set 6 | gazni
# City not found. Skipping...
# Processing Record 30 of Set 6 | nantucket
# Processing Record 31 of Set 6 | iquique
# Processing Record 32 of Set 6 | kizhinga
# Processing Record 33 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 34 of Set 6 | katobu
# Processing Record 35 of Set 6 | cherskiy
# Processing Record 36 of Set 6 | lima
# Processing Record 37 of Set 6 | wangkui
# Processing Record 38 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 6 | boueni
# Processing Record 40 of Set 6 | saldanha
# Processing Record 41 of Set 6 | lingsugur
# Processing Record 42 of Set 6 | kloulklubed
# Processing Record 43 of Set 6 | suntar
# Processing Record 44 of Set 6 | takoradi
# Processing Record 45 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 6 | meulaboh
# Processing Record 47 of Set 6 | santa cruz cabralia
# Processing Record 48 of Set 6 | abnub
# Processing Record 49 of Set 6 | alekseyevka
# Processing Record 50 of Set 6 | altoona
# Processing Record 1 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 2 of Set 7 | abu samrah
# Processing Record 3 of Set 7 | mawlaik
# Processing Record 4 of Set 7 | tandalti
# Processing Record 5 of Set 7 | labuhan
# Processing Record 6 of Set 7 | santa maria del oro
# Processing Record 7 of Set 7 | niamey
# Processing Record 8 of Set 7 | skiros
# City not found. Skipping...
# Processing Record 9 of Set 7 | waingapu
# Processing Record 10 of Set 7 | ayr
# Processing Record 11 of Set 7 | agadez
# Processing Record 12 of Set 7 | baghdogra
# Processing Record 13 of Set 7 | olafsvik
# Processing Record 14 of Set 7 | piribebuy
# Processing Record 15 of Set 7 | huaihua
# Processing Record 16 of Set 7 | podor
# Processing Record 17 of Set 7 | changping
# Processing Record 18 of Set 7 | hovd
# Processing Record 19 of Set 7 | alofi
# Processing Record 20 of Set 7 | wurzburg
# Processing Record 21 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 7 | portland
# Processing Record 24 of Set 7 | muros
# Processing Record 25 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 26 of Set 7 | slavonski brod
# Processing Record 27 of Set 7 | willmar
# Processing Record 28 of Set 7 | geraldton
# Processing Record 29 of Set 7 | gamboma
# Processing Record 30 of Set 7 | maldonado
# Processing Record 31 of Set 7 | algiers
# Processing Record 32 of Set 7 | carauari
# Processing Record 33 of Set 7 | newcastle
# Processing Record 34 of Set 7 | east london
# Processing Record 35 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 36 of Set 7 | maningrida
# Processing Record 37 of Set 7 | vestmannaeyjar
# Processing Record 38 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 39 of Set 7 | gotsu
# Processing Record 40 of Set 7 | yerbogachen
# Processing Record 41 of Set 7 | egvekinot
# Processing Record 42 of Set 7 | vostok
# Processing Record 43 of Set 7 | chabahar
# Processing Record 44 of Set 7 | mercedes
# Processing Record 45 of Set 7 | hofn
# Processing Record 46 of Set 7 | tena
# Processing Record 47 of Set 7 | grand-santi
# Processing Record 48 of Set 7 | aberdeen
# Processing Record 49 of Set 7 | saint-philippe
# Processing Record 50 of Set 7 | banfora
# Processing Record 1 of Set 8 | dingle
# Processing Record 2 of Set 8 | oktyabrskiy
# Processing Record 3 of Set 8 | serov
# Processing Record 4 of Set 8 | saint-pacome
# City not found. Skipping...
# Processing Record 5 of Set 8 | kungurtug
# Processing Record 6 of Set 8 | hamilton
# Processing Record 7 of Set 8 | synya
# Processing Record 8 of Set 8 | songkhla
# Processing Record 9 of Set 8 | inirida
# Processing Record 10 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 8 | kiama
# Processing Record 12 of Set 8 | sibolga
# Processing Record 13 of Set 8 | kaitangata
# Processing Record 14 of Set 8 | bambous virieux
# Processing Record 15 of Set 8 | chardara
# Processing Record 16 of Set 8 | dudinka
# Processing Record 17 of Set 8 | along
# Processing Record 18 of Set 8 | quatre cocos
# Processing Record 19 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 20 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 21 of Set 8 | atascadero
# Processing Record 22 of Set 8 | olean
# Processing Record 23 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 24 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 8 | guerrero negro
# Processing Record 26 of Set 8 | hammerfest
# Processing Record 27 of Set 8 | diu
# Processing Record 28 of Set 8 | rab
# City not found. Skipping...
# Processing Record 29 of Set 8 | uppsala
# Processing Record 30 of Set 8 | sabya
# Processing Record 31 of Set 8 | fare
# Processing Record 32 of Set 8 | lavrentiya
# Processing Record 33 of Set 8 | puerto santander
# Processing Record 34 of Set 8 | husavik
# Processing Record 35 of Set 8 | gangotri
# City not found. Skipping...
# Processing Record 36 of Set 8 | saint-augustin
# Processing Record 37 of Set 8 | port macquarie
# Processing Record 38 of Set 8 | nador
# Processing Record 39 of Set 8 | kurumkan
# Processing Record 40 of Set 8 | chapada dos guimaraes
# Processing Record 41 of Set 8 | pangkalanbuun
# Processing Record 42 of Set 8 | vila velha
# Processing Record 43 of Set 8 | higuey
# City not found. Skipping...
# Processing Record 44 of Set 8 | timmins
# Processing Record 45 of Set 8 | wakkanai
# Processing Record 46 of Set 8 | planadas
# Processing Record 47 of Set 8 | noumea
# Processing Record 48 of Set 8 | sabang
# Processing Record 49 of Set 8 | udachnyy
# Processing Record 50 of Set 8 | airai
# Processing Record 1 of Set 9 | umea
# Processing Record 2 of Set 9 | tuatapere
# Processing Record 3 of Set 9 | fuerte
# Processing Record 4 of Set 9 | touros
# Processing Record 5 of Set 9 | shchigry
# Processing Record 6 of Set 9 | mangai
# Processing Record 7 of Set 9 | caravelas
# Processing Record 8 of Set 9 | latung
# Processing Record 9 of Set 9 | simpang
# Processing Record 10 of Set 9 | asyut
# Processing Record 11 of Set 9 | koslan
# Processing Record 12 of Set 9 | nanzhou
# Processing Record 13 of Set 9 | cervo
# Processing Record 14 of Set 9 | filadelfia
# Processing Record 15 of Set 9 | cockburn town
# Processing Record 16 of Set 9 | berlevag
# Processing Record 17 of Set 9 | cascais
# Processing Record 18 of Set 9 | lerwick
# Processing Record 19 of Set 9 | isangel
# Processing Record 20 of Set 9 | margate
# Processing Record 21 of Set 9 | wuda
# Processing Record 22 of Set 9 | huarmey
# Processing Record 23 of Set 9 | lazaro cardenas
# Processing Record 24 of Set 9 | manggar
# Processing Record 25 of Set 9 | dong hoi
# Processing Record 26 of Set 9 | lovozero
# Processing Record 27 of Set 9 | boyolangu
# Processing Record 28 of Set 9 | thompson
# Processing Record 29 of Set 9 | kaliganj
# Processing Record 30 of Set 9 | betare oya
# Processing Record 31 of Set 9 | olinda
# Processing Record 32 of Set 9 | viedma
# Processing Record 33 of Set 9 | kota kinabalu
# Processing Record 34 of Set 9 | nipawin
# Processing Record 35 of Set 9 | isla aguada
# Processing Record 36 of Set 9 | arica
# Processing Record 37 of Set 9 | asosa
# Processing Record 38 of Set 9 | half moon bay
# Processing Record 39 of Set 9 | wuchi
# Processing Record 40 of Set 9 | sioux lookout
# Processing Record 41 of Set 9 | doha
# Processing Record 42 of Set 9 | cizre
# Processing Record 43 of Set 9 | dalbandin
# Processing Record 44 of Set 9 | pundaguitan
# Processing Record 45 of Set 9 | vardo
# Processing Record 46 of Set 9 | palapye
# Processing Record 47 of Set 9 | ishigaki
# Processing Record 48 of Set 9 | devonport
# Processing Record 49 of Set 9 | brzeg dolny
# Processing Record 50 of Set 9 | dalhousie
# Processing Record 1 of Set 10 | wad rawah
# Processing Record 2 of Set 10 | melito di porto salvo
# Processing Record 3 of Set 10 | yatou
# Processing Record 4 of Set 10 | erzin
# Processing Record 5 of Set 10 | pangai
# Processing Record 6 of Set 10 | nizwa
# Processing Record 7 of Set 10 | piacabucu
# Processing Record 8 of Set 10 | maceio
# Processing Record 9 of Set 10 | okhotsk
# Processing Record 10 of Set 10 | ossora
# Processing Record 11 of Set 10 | gerash
# Processing Record 12 of Set 10 | coos bay
# Processing Record 13 of Set 10 | erenhot
# Processing Record 14 of Set 10 | rawson
# Processing Record 15 of Set 10 | mount gambier
# Processing Record 16 of Set 10 | bambanglipuro
# Processing Record 17 of Set 10 | banda aceh
# Processing Record 18 of Set 10 | jalapa
# Processing Record 19 of Set 10 | tuy hoa
# Processing Record 20 of Set 10 | buqayq
# City not found. Skipping...
# Processing Record 21 of Set 10 | palu
# Processing Record 22 of Set 10 | oranjestad
# Processing Record 23 of Set 10 | arlit
# Processing Record 24 of Set 10 | fort morgan
# Processing Record 25 of Set 10 | tezu
# Processing Record 26 of Set 10 | ipira
# Processing Record 27 of Set 10 | fonte boa
# Processing Record 28 of Set 10 | anadyr
# Processing Record 29 of Set 10 | santo tomas
# Processing Record 30 of Set 10 | krasnyy yar
# Processing Record 31 of Set 10 | buchanan
# Processing Record 32 of Set 10 | prince rupert
# Processing Record 33 of Set 10 | alta floresta
# Processing Record 34 of Set 10 | waitati
# Processing Record 35 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 36 of Set 10 | chuguyevka
# Processing Record 37 of Set 10 | beringovskiy
# Processing Record 38 of Set 10 | verkhnyaya inta
# Processing Record 39 of Set 10 | ust-kut
# Processing Record 40 of Set 10 | keuruu
# Processing Record 41 of Set 10 | codrington
# Processing Record 42 of Set 10 | port hardy
# Processing Record 43 of Set 10 | turayf
# Processing Record 44 of Set 10 | wencheng
# Processing Record 45 of Set 10 | qaqortoq
# Processing Record 46 of Set 10 | churapcha
# Processing Record 47 of Set 10 | whitman
# Processing Record 48 of Set 10 | ulaangom
# Processing Record 49 of Set 10 | gao
# Processing Record 50 of Set 10 | sorland
# Processing Record 1 of Set 11 | wajid
# Processing Record 2 of Set 11 | kulhudhuffushi
# Processing Record 3 of Set 11 | havre-saint-pierre
# Processing Record 4 of Set 11 | ampanihy
# Processing Record 5 of Set 11 | marsh harbour
# Processing Record 6 of Set 11 | sao filipe
# Processing Record 7 of Set 11 | jinxiang
# Processing Record 8 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 9 of Set 11 | valley city
# Processing Record 10 of Set 11 | huangnihe
# Processing Record 11 of Set 11 | danjiangkou
# Processing Record 12 of Set 11 | multan
# Processing Record 13 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 14 of Set 11 | fairbanks
# Processing Record 15 of Set 11 | eureka
# Processing Record 16 of Set 11 | atlantic city
# Processing Record 17 of Set 11 | henderson
# Processing Record 18 of Set 11 | pokhara
# Processing Record 19 of Set 11 | rocha
# Processing Record 20 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 21 of Set 11 | pringsewu
# Processing Record 22 of Set 11 | novikovo
# Processing Record 23 of Set 11 | talnakh
# Processing Record 24 of Set 11 | asifabad
# Processing Record 25 of Set 11 | villamontes
# Processing Record 26 of Set 11 | nola
# Processing Record 27 of Set 11 | ahumada
# City not found. Skipping...
# Processing Record 28 of Set 11 | whitehorse
# Processing Record 29 of Set 11 | naze
# Processing Record 30 of Set 11 | linxia
# Processing Record 31 of Set 11 | tambovka
# Processing Record 32 of Set 11 | colwyn bay
# Processing Record 33 of Set 11 | luanda
# Processing Record 34 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 35 of Set 11 | galle
# Processing Record 36 of Set 11 | port shepstone
# Processing Record 37 of Set 11 | lorengau
# Processing Record 38 of Set 11 | nemuro
# Processing Record 39 of Set 11 | wanxian
# Processing Record 40 of Set 11 | ucluelet
# Processing Record 41 of Set 11 | goshogawara
# Processing Record 42 of Set 11 | kondinskoye
# Processing Record 43 of Set 11 | uige
# Processing Record 44 of Set 11 | sawakin
# Processing Record 45 of Set 11 | kabalo
# Processing Record 46 of Set 11 | rodrigues alves
# Processing Record 47 of Set 11 | manhuacu
# Processing Record 48 of Set 11 | qandala
# Processing Record 49 of Set 11 | progreso
# Processing Record 50 of Set 11 | boddam
# Processing Record 1 of Set 12 | sao gabriel da cachoeira
# Processing Record 2 of Set 12 | nea artaki
# Processing Record 3 of Set 12 | saint-andre
# Processing Record 4 of Set 12 | shingu
# Processing Record 5 of Set 12 | beloha
# Processing Record 6 of Set 12 | gazanjyk
# Processing Record 7 of Set 12 | pandan
# Processing Record 8 of Set 12 | batemans bay
# Processing Record 9 of Set 12 | havoysund
# Processing Record 10 of Set 12 | shediac
# Processing Record 11 of Set 12 | jingdezhen
# Processing Record 12 of Set 12 | plettenberg bay
# Processing Record 13 of Set 12 | la palma
# Processing Record 14 of Set 12 | kailua
# Processing Record 15 of Set 12 | selma
# Processing Record 16 of Set 12 | luwuk
# Processing Record 17 of Set 12 | reconquista
# Processing Record 18 of Set 12 | san juan
# Processing Record 19 of Set 12 | lompoc
# Processing Record 20 of Set 12 | belaya gora
# Processing Record 21 of Set 12 | axim
# Processing Record 22 of Set 12 | yarkovo
# Processing Record 23 of Set 12 | loa janan
# Processing Record 24 of Set 12 | san andres
# Processing Record 25 of Set 12 | sault sainte marie
# Processing Record 26 of Set 12 | taveta
# Processing Record 27 of Set 12 | kilbirnie
# Processing Record 28 of Set 12 | yumen
# Processing Record 29 of Set 12 | porterville
# Processing Record 30 of Set 12 | weligama
# Processing Record 31 of Set 12 | igrim
# Processing Record 32 of Set 12 | taltal
# Processing Record 33 of Set 12 | nenita
# Processing Record 34 of Set 12 | ornskoldsvik
# Processing Record 35 of Set 12 | cruces
# Processing Record 36 of Set 12 | karakendzha
# City not found. Skipping...
# Processing Record 37 of Set 12 | norwalk
# Processing Record 38 of Set 12 | mundo nuevo
# Processing Record 39 of Set 12 | paka
# Processing Record 40 of Set 12 | hualmay
# Processing Record 41 of Set 12 | vila franca do campo
# Processing Record 42 of Set 12 | shubarkuduk
# Processing Record 43 of Set 12 | xining
# Processing Record 44 of Set 12 | bandar-e lengeh
# Processing Record 45 of Set 12 | yar-sale
# Processing Record 46 of Set 12 | trairi
# Processing Record 47 of Set 12 | saint-francois
# Processing Record 48 of Set 12 | misratah
# Processing Record 49 of Set 12 | edson
# Processing Record 50 of Set 12 | merauke
# Processing Record 1 of Set 13 | payo
# Processing Record 2 of Set 13 | te anau
# Processing Record 3 of Set 13 | kuching
# Processing Record 4 of Set 13 | yeppoon
# Processing Record 5 of Set 13 | jinchengjiang
# City not found. Skipping...
# Processing Record 6 of Set 13 | coihaique
# Processing Record 7 of Set 13 | bestobe
# Processing Record 8 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 9 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 10 of Set 13 | san borja
# Processing Record 11 of Set 13 | adrar
# Processing Record 12 of Set 13 | alihe
# Processing Record 13 of Set 13 | snasa
# Processing Record 14 of Set 13 | gamba
# Processing Record 15 of Set 13 | ambulu
# Processing Record 16 of Set 13 | sarakhs
# Processing Record 17 of Set 13 | krabi
# Processing Record 18 of Set 13 | minas
# Processing Record 19 of Set 13 | bokoro
# Processing Record 20 of Set 13 | linao
# Processing Record 21 of Set 13 | manga
# Processing Record 22 of Set 13 | bukama
# Processing Record 23 of Set 13 | azimur
# City not found. Skipping...
# Processing Record 24 of Set 13 | saint anthony
# Processing Record 25 of Set 13 | gushikawa
# Processing Record 26 of Set 13 | le mars
# Processing Record 27 of Set 13 | hare bay
# Processing Record 28 of Set 13 | zhigansk
# Processing Record 29 of Set 13 | amboasary
# Processing Record 30 of Set 13 | nokaneng
# Processing Record 31 of Set 13 | porto santo
# Processing Record 32 of Set 13 | ankazoabo
# Processing Record 33 of Set 13 | kushima
# Processing Record 34 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 35 of Set 13 | conakry
# Processing Record 36 of Set 13 | majene
# Processing Record 37 of Set 13 | bulawayo
# Processing Record 38 of Set 13 | ullapool
# Processing Record 39 of Set 13 | swellendam
# Processing Record 40 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 41 of Set 13 | pa sang
# Processing Record 42 of Set 13 | cheuskiny
# City not found. Skipping...
# Processing Record 43 of Set 13 | inhambane
# Processing Record 44 of Set 13 | otjimbingwe
# Processing Record 45 of Set 13 | jiangyou
# Processing Record 46 of Set 13 | karratha
# Processing Record 47 of Set 13 | alberton
# Processing Record 48 of Set 13 | morondava
# Processing Record 49 of Set 13 | gambo
# Processing Record 50 of Set 13 | usinsk
# Processing Record 1 of Set 14 | oistins
# Processing Record 2 of Set 14 | barra da estiva
# Processing Record 3 of Set 14 | kudahuvadhoo
# Processing Record 4 of Set 14 | khuzhir
# Processing Record 5 of Set 14 | teya
# Processing Record 6 of Set 14 | curup
# Processing Record 7 of Set 14 | kirakira
# Processing Record 8 of Set 14 | westport
# Processing Record 9 of Set 14 | juneau
# Processing Record 10 of Set 14 | tual
# Processing Record 11 of Set 14 | xinmin
# Processing Record 12 of Set 14 | ruidoso
# Processing Record 13 of Set 14 | le vauclin
# Processing Record 14 of Set 14 | kadirli
# Processing Record 15 of Set 14 | tuggurt
# City not found. Skipping...
# Processing Record 16 of Set 14 | beneditinos
# Processing Record 17 of Set 14 | port blair
# Processing Record 18 of Set 14 | gonaives
# Processing Record 19 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 20 of Set 14 | el cristo
# Processing Record 21 of Set 14 | portobelo
# Processing Record 22 of Set 14 | northam
# Processing Record 23 of Set 14 | charlestown
# Processing Record 24 of Set 14 | chum phae
# Processing Record 25 of Set 14 | nanyamba
# Processing Record 26 of Set 14 | migori
# Processing Record 27 of Set 14 | padang
# Processing Record 28 of Set 14 | osijek
# Processing Record 29 of Set 14 | kuvandyk
# Processing Record 30 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 14 | flinders
# Processing Record 32 of Set 14 | keflavik
# Processing Record 33 of Set 14 | smiths falls
# Processing Record 34 of Set 14 | carutapera
# Processing Record 35 of Set 14 | port saint lucie
# Processing Record 36 of Set 14 | zhezkazgan
# Processing Record 37 of Set 14 | ukholovo
# Processing Record 38 of Set 14 | samarai
# Processing Record 39 of Set 14 | san carlos de bariloche
# Processing Record 40 of Set 14 | davenport
# Processing Record 41 of Set 14 | kamalapuram
# Processing Record 42 of Set 14 | veraval
# Processing Record 43 of Set 14 | malanje
# Processing Record 44 of Set 14 | petrivka
# Processing Record 45 of Set 14 | galiwinku
# City not found. Skipping...
# Processing Record 46 of Set 14 | beloyarskiy
# Processing Record 47 of Set 14 | wulanhaote
# City not found. Skipping...
# Processing Record 48 of Set 14 | kansanshi
# Processing Record 49 of Set 14 | tera
# Processing Record 50 of Set 14 | verkh-usugli
# Processing Record 1 of Set 15 | tandil
# Processing Record 2 of Set 15 | guangyuan
# Processing Record 3 of Set 15 | laguna
# Processing Record 4 of Set 15 | coquimbo
# Processing Record 5 of Set 15 | vangaindrano
# Processing Record 6 of Set 15 | ahipara
# Processing Record 7 of Set 15 | blagoyevo
# Processing Record 8 of Set 15 | ban nahin
# Processing Record 9 of Set 15 | mouzakion
# City not found. Skipping...
# Processing Record 10 of Set 15 | makakilo city
# Processing Record 11 of Set 15 | preobrazhenskaya
# City not found. Skipping...
# Processing Record 12 of Set 15 | tautira
# Processing Record 13 of Set 15 | nishihara
# Processing Record 14 of Set 15 | tura
# Processing Record 15 of Set 15 | acarau
# Processing Record 16 of Set 15 | nagorsk
# Processing Record 17 of Set 15 | emerald
# Processing Record 18 of Set 15 | puerto lleras
# Processing Record 19 of Set 15 | caluquembe
# Processing Record 20 of Set 15 | kattivakkam
# Processing Record 21 of Set 15 | cambridge
# Processing Record 22 of Set 15 | bintulu
# Processing Record 23 of Set 15 | melilla
# Processing Record 24 of Set 15 | moranbah
# Processing Record 25 of Set 15 | galesong
# Processing Record 26 of Set 15 | batagay-alyta
# Processing Record 27 of Set 15 | pauini
# Processing Record 28 of Set 15 | pisz
# Processing Record 29 of Set 15 | santa rosa
# Processing Record 30 of Set 15 | preutesti
# Processing Record 31 of Set 15 | ust-omchug
# Processing Record 32 of Set 15 | klaksvik
# Processing Record 33 of Set 15 | mitsamiouli
# Processing Record 34 of Set 15 | isla vista
# Processing Record 35 of Set 15 | shancheng
# Processing Record 36 of Set 15 | topolobampo
# Processing Record 37 of Set 15 | broken hill
# Processing Record 38 of Set 15 | shelburne
# Processing Record 39 of Set 15 | kigoma
# Processing Record 40 of Set 15 | novyy urengoy
# Processing Record 41 of Set 15 | hailar
# Processing Record 42 of Set 15 | hokitika
# Processing Record 43 of Set 15 | vestmanna
# Processing Record 44 of Set 15 | oranjemund
# Processing Record 45 of Set 15 | nawa
# Processing Record 46 of Set 15 | henties bay
# Processing Record 47 of Set 15 | stornoway
# Processing Record 48 of Set 15 | yeehaw junction
# City not found. Skipping...
# Processing Record 49 of Set 15 | salalah
# Processing Record 50 of Set 15 | dovolnoye
# Processing Record 1 of Set 16 | sucua
# Processing Record 2 of Set 16 | dharchula
# Processing Record 3 of Set 16 | belyy yar
# Processing Record 4 of Set 16 | magadan
# Processing Record 5 of Set 16 | durres
# Processing Record 6 of Set 16 | kargapolye
# City not found. Skipping...
# Processing Record 7 of Set 16 | tres arroyos
# Processing Record 8 of Set 16 | kangaatsiaq
# Processing Record 9 of Set 16 | hereford
# Processing Record 10 of Set 16 | matay
# Processing Record 11 of Set 16 | sao felix do xingu
# Processing Record 12 of Set 16 | arys
# Processing Record 13 of Set 16 | dunda
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 701

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Busselton -33.6500  115.3333     70.11        51          77
# 1          Taft  31.7471   54.2088     78.75        10           0
# 2  San Patricio  28.0170  -97.5169     78.84        56           0
# 3     Mahebourg -20.4081   57.7000     76.24        68          75
# 4  Saint George  37.1041 -113.5841     78.26        36           0
# 5      Khatanga  71.9667  102.5000     31.23        96         100
# 6     Mount Isa -20.7333  139.5000     83.97        17          99
# 7    Bredasdorp -34.5322   20.0403     58.05        70         100
# 8       Mataura -46.1927  168.8643     51.48        56           0
# 9   Verkhoturye  58.8627   60.8054     37.58        51          61
#
#    Wind Speed Country Current Description
# 0       11.88      AU       broken clouds
# 1        2.30      IR           clear sky
# 2        6.93      US           clear sky
# 3        9.22      MU       broken clouds
# 4        8.05      US           clear sky
# 5       14.47      RU          light snow
# 6        4.61      AU     overcast clouds
# 7        2.33      ZA     overcast clouds
# 8        5.08      NZ           clear sky
# 9        7.96      RU       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df= city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Busselton      AU -33.6500  115.3333     70.11        51          77
# 1          Taft      IR  31.7471   54.2088     78.75        10           0
# 2  San Patricio      US  28.0170  -97.5169     78.84        56           0
# 3     Mahebourg      MU -20.4081   57.7000     76.24        68          75
# 4  Saint George      US  37.1041 -113.5841     78.26        36           0
# 5      Khatanga      RU  71.9667  102.5000     31.23        96         100
# 6     Mount Isa      AU -20.7333  139.5000     83.97        17          99
# 7    Bredasdorp      ZA -34.5322   20.0403     58.05        70         100
# 8       Mataura      NZ -46.1927  168.8643     51.48        56           0
# 9   Verkhoturye      RU  58.8627   60.8054     37.58        51          61
#
#    Wind Speed Current Description
# 0       11.88       broken clouds
# 1        2.30           clear sky
# 2        6.93           clear sky
# 3        9.22       broken clouds
# 4        8.05           clear sky
# 5       14.47          light snow
# 6        4.61     overcast clouds
# 7        2.33     overcast clouds
# 8        5.08           clear sky
# 9        7.96       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
