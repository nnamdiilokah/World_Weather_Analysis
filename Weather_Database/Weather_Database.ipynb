# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000,high=90.000,size=2000)
lngs = np.random.uniform(low=-180.000,high=180.000,size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 745

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]      
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')           
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | ambovombe
# Processing Record 3 of Set 1 | kungurtug
# Processing Record 4 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 1 | narsaq
# Processing Record 6 of Set 1 | gambela
# Processing Record 7 of Set 1 | tasiilaq
# Processing Record 8 of Set 1 | bredasdorp
# Processing Record 9 of Set 1 | thompson
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | natal
# Processing Record 12 of Set 1 | fortuna
# Processing Record 13 of Set 1 | mahebourg
# Processing Record 14 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 1 | lac du bonnet
# Processing Record 16 of Set 1 | kodiak
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | touros
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | lukovetskiy
# Processing Record 22 of Set 1 | aklavik
# Processing Record 23 of Set 1 | sangar
# Processing Record 24 of Set 1 | wattegama
# Processing Record 25 of Set 1 | henties bay
# Processing Record 26 of Set 1 | fomboni
# Processing Record 27 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 1 | takestan
# Processing Record 29 of Set 1 | rawson
# Processing Record 30 of Set 1 | rincon
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | sergeyevka
# Processing Record 33 of Set 1 | tura
# Processing Record 34 of Set 1 | sorland
# Processing Record 35 of Set 1 | shingu
# Processing Record 36 of Set 1 | padang
# Processing Record 37 of Set 1 | tiksi
# Processing Record 38 of Set 1 | saldanha
# Processing Record 39 of Set 1 | ancud
# Processing Record 40 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 1 | punta arenas
# Processing Record 42 of Set 1 | lebu
# Processing Record 43 of Set 1 | atasu
# Processing Record 44 of Set 1 | hendrina
# Processing Record 45 of Set 1 | clyde river
# Processing Record 46 of Set 1 | kommunisticheskiy
# Processing Record 47 of Set 1 | bluff
# Processing Record 48 of Set 1 | fakel
# Processing Record 49 of Set 1 | victoria
# Processing Record 50 of Set 1 | port elizabeth
# Processing Record 1 of Set 2 | dikson
# Processing Record 2 of Set 2 | rodrigues alves
# Processing Record 3 of Set 2 | cayenne
# Processing Record 4 of Set 2 | arman
# Processing Record 5 of Set 2 | belyy yar
# Processing Record 6 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 7 of Set 2 | barrow
# Processing Record 8 of Set 2 | yellowknife
# Processing Record 9 of Set 2 | rolim de moura
# City not found. Skipping...
# Processing Record 10 of Set 2 | hermanus
# Processing Record 11 of Set 2 | lompoc
# Processing Record 12 of Set 2 | nenjiang
# Processing Record 13 of Set 2 | lagoa
# Processing Record 14 of Set 2 | moshenskoye
# Processing Record 15 of Set 2 | talnakh
# Processing Record 16 of Set 2 | atuona
# Processing Record 17 of Set 2 | saint-pierre
# Processing Record 18 of Set 2 | kapaa
# Processing Record 19 of Set 2 | vostok
# Processing Record 20 of Set 2 | danielskuil
# Processing Record 21 of Set 2 | rikitea
# Processing Record 22 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 2 | toora-khem
# Processing Record 24 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 2 | raudeberg
# Processing Record 26 of Set 2 | avarua
# Processing Record 27 of Set 2 | tuktoyaktuk
# Processing Record 28 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 2 | meulaboh
# Processing Record 30 of Set 2 | hilo
# Processing Record 31 of Set 2 | hithadhoo
# Processing Record 32 of Set 2 | ilulissat
# Processing Record 33 of Set 2 | svetlogorsk
# Processing Record 34 of Set 2 | cape town
# Processing Record 35 of Set 2 | cabedelo
# Processing Record 36 of Set 2 | emerald
# Processing Record 37 of Set 2 | esperance
# Processing Record 38 of Set 2 | columbia
# Processing Record 39 of Set 2 | praia da vitoria
# Processing Record 40 of Set 2 | port alfred
# Processing Record 41 of Set 2 | los llanos de aridane
# Processing Record 42 of Set 2 | atar
# Processing Record 43 of Set 2 | saint-philippe
# Processing Record 44 of Set 2 | butaritari
# Processing Record 45 of Set 2 | san rafael
# Processing Record 46 of Set 2 | qaanaaq
# Processing Record 47 of Set 2 | koslan
# Processing Record 48 of Set 2 | castro
# Processing Record 49 of Set 2 | pavlodar
# Processing Record 50 of Set 2 | guerrero negro
# Processing Record 1 of Set 3 | kavieng
# Processing Record 2 of Set 3 | chuy
# Processing Record 3 of Set 3 | san patricio
# Processing Record 4 of Set 3 | san quintin
# Processing Record 5 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 3 | morant bay
# Processing Record 7 of Set 3 | laje
# Processing Record 8 of Set 3 | hobart
# Processing Record 9 of Set 3 | diffa
# Processing Record 10 of Set 3 | kieta
# Processing Record 11 of Set 3 | isangel
# Processing Record 12 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 3 | luanda
# Processing Record 14 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 15 of Set 3 | puerto ayora
# Processing Record 16 of Set 3 | bur gabo
# City not found. Skipping...
# Processing Record 17 of Set 3 | gari
# Processing Record 18 of Set 3 | orlandia
# Processing Record 19 of Set 3 | panzhihua
# Processing Record 20 of Set 3 | kahului
# Processing Record 21 of Set 3 | arrifes
# Processing Record 22 of Set 3 | torbay
# Processing Record 23 of Set 3 | muroto
# Processing Record 24 of Set 3 | lufilufi
# Processing Record 25 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 3 | vila
# Processing Record 27 of Set 3 | ribeira grande
# Processing Record 28 of Set 3 | upernavik
# Processing Record 29 of Set 3 | barranca
# Processing Record 30 of Set 3 | dudinka
# Processing Record 31 of Set 3 | arraial do cabo
# Processing Record 32 of Set 3 | sao filipe
# Processing Record 33 of Set 3 | antofagasta
# Processing Record 34 of Set 3 | saint-gaudens
# Processing Record 35 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 3 | beyneu
# Processing Record 37 of Set 3 | yukhnov
# Processing Record 38 of Set 3 | termiz
# Processing Record 39 of Set 3 | goundam
# Processing Record 40 of Set 3 | provideniya
# Processing Record 41 of Set 3 | port lincoln
# Processing Record 42 of Set 3 | georgetown
# Processing Record 43 of Set 3 | gat
# Processing Record 44 of Set 3 | norman wells
# Processing Record 45 of Set 3 | wanaka
# Processing Record 46 of Set 3 | antsohihy
# Processing Record 47 of Set 3 | severo-kurilsk
# Processing Record 48 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 3 | bubaque
# Processing Record 50 of Set 3 | egvekinot
# Processing Record 1 of Set 4 | sayyan
# Processing Record 2 of Set 4 | mar del plata
# Processing Record 3 of Set 4 | sitka
# Processing Record 4 of Set 4 | jamestown
# Processing Record 5 of Set 4 | hofn
# Processing Record 6 of Set 4 | yanam
# Processing Record 7 of Set 4 | innisfail
# Processing Record 8 of Set 4 | coquimbo
# Processing Record 9 of Set 4 | pervoye maya
# Processing Record 10 of Set 4 | puerto carreno
# Processing Record 11 of Set 4 | new norfolk
# Processing Record 12 of Set 4 | fort nelson
# Processing Record 13 of Set 4 | waingapu
# Processing Record 14 of Set 4 | longyearbyen
# Processing Record 15 of Set 4 | giyani
# Processing Record 16 of Set 4 | phnum penh
# City not found. Skipping...
# Processing Record 17 of Set 4 | darlowo
# Processing Record 18 of Set 4 | leh
# Processing Record 19 of Set 4 | katsuura
# Processing Record 20 of Set 4 | saint anthony
# Processing Record 21 of Set 4 | riyadh
# Processing Record 22 of Set 4 | kruisfontein
# Processing Record 23 of Set 4 | wanning
# Processing Record 24 of Set 4 | gainesville
# Processing Record 25 of Set 4 | airai
# Processing Record 26 of Set 4 | pemangkat
# Processing Record 27 of Set 4 | nikolsk
# Processing Record 28 of Set 4 | iquique
# Processing Record 29 of Set 4 | alofi
# Processing Record 30 of Set 4 | tautira
# Processing Record 31 of Set 4 | vestmannaeyjar
# Processing Record 32 of Set 4 | harper
# Processing Record 33 of Set 4 | el alto
# Processing Record 34 of Set 4 | chuzhou
# Processing Record 35 of Set 4 | tessalit
# Processing Record 36 of Set 4 | ugoofaaru
# Processing Record 37 of Set 4 | hamilton
# Processing Record 38 of Set 4 | pisco
# Processing Record 39 of Set 4 | tunduru
# City not found. Skipping...
# Processing Record 40 of Set 4 | carnarvon
# Processing Record 41 of Set 4 | linxia
# Processing Record 42 of Set 4 | darasun
# Processing Record 43 of Set 4 | geraldton
# Processing Record 44 of Set 4 | pevek
# Processing Record 45 of Set 4 | ulaangom
# Processing Record 46 of Set 4 | arkhipovka
# Processing Record 47 of Set 4 | kota kinabalu
# Processing Record 48 of Set 4 | qaqortoq
# Processing Record 49 of Set 4 | swift current
# Processing Record 50 of Set 4 | grindavik
# Processing Record 1 of Set 5 | luderitz
# Processing Record 2 of Set 5 | adre
# Processing Record 3 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 4 of Set 5 | tay ninh
# Processing Record 5 of Set 5 | belmonte
# Processing Record 6 of Set 5 | weinan
# Processing Record 7 of Set 5 | hammerfest
# Processing Record 8 of Set 5 | cerrito
# Processing Record 9 of Set 5 | olafsvik
# Processing Record 10 of Set 5 | shache
# Processing Record 11 of Set 5 | caldwell
# Processing Record 12 of Set 5 | komsomolskiy
# Processing Record 13 of Set 5 | columbus
# Processing Record 14 of Set 5 | yokadouma
# Processing Record 15 of Set 5 | shunyi
# Processing Record 16 of Set 5 | san carlos de bariloche
# Processing Record 17 of Set 5 | marsaxlokk
# Processing Record 18 of Set 5 | saskylakh
# Processing Record 19 of Set 5 | seryshevo
# Processing Record 20 of Set 5 | alugan
# Processing Record 21 of Set 5 | ormara
# Processing Record 22 of Set 5 | buchanan
# Processing Record 23 of Set 5 | dwarka
# Processing Record 24 of Set 5 | mineros
# Processing Record 25 of Set 5 | nikolskoye
# Processing Record 26 of Set 5 | aden
# Processing Record 27 of Set 5 | samana
# Processing Record 28 of Set 5 | aktash
# Processing Record 29 of Set 5 | east london
# Processing Record 30 of Set 5 | huarmey
# Processing Record 31 of Set 5 | sarakhs
# Processing Record 32 of Set 5 | hauterive
# Processing Record 33 of Set 5 | agaro
# Processing Record 34 of Set 5 | gallipoli
# Processing Record 35 of Set 5 | chokurdakh
# Processing Record 36 of Set 5 | do gonbadan
# Processing Record 37 of Set 5 | souillac
# Processing Record 38 of Set 5 | chibombo
# Processing Record 39 of Set 5 | kavaratti
# Processing Record 40 of Set 5 | kang
# Processing Record 41 of Set 5 | bengkulu
# Processing Record 42 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 5 | marsa matruh
# Processing Record 44 of Set 5 | liniere
# City not found. Skipping...
# Processing Record 45 of Set 5 | samfya
# Processing Record 46 of Set 5 | vila velha
# Processing Record 47 of Set 5 | chapais
# Processing Record 48 of Set 5 | port hedland
# Processing Record 49 of Set 5 | biak
# Processing Record 50 of Set 5 | morros
# Processing Record 1 of Set 6 | buraydah
# Processing Record 2 of Set 6 | north fort myers
# Processing Record 3 of Set 6 | grootfontein
# Processing Record 4 of Set 6 | ahipara
# Processing Record 5 of Set 6 | tigil
# Processing Record 6 of Set 6 | bambanglipuro
# Processing Record 7 of Set 6 | comodoro rivadavia
# Processing Record 8 of Set 6 | bambous virieux
# Processing Record 9 of Set 6 | cozumel
# Processing Record 10 of Set 6 | arlit
# Processing Record 11 of Set 6 | tuatapere
# Processing Record 12 of Set 6 | mattru
# Processing Record 13 of Set 6 | hami
# Processing Record 14 of Set 6 | tateyama
# Processing Record 15 of Set 6 | kirensk
# Processing Record 16 of Set 6 | klaksvik
# Processing Record 17 of Set 6 | cabo san lucas
# Processing Record 18 of Set 6 | eureka
# Processing Record 19 of Set 6 | riosucio
# Processing Record 20 of Set 6 | cortland
# Processing Record 21 of Set 6 | tiruvottiyur
# City not found. Skipping...
# Processing Record 22 of Set 6 | tomatlan
# Processing Record 23 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 6 | ascona
# Processing Record 25 of Set 6 | marienburg
# Processing Record 26 of Set 6 | saint george
# Processing Record 27 of Set 6 | korfez
# Processing Record 28 of Set 6 | bulgan
# Processing Record 29 of Set 6 | maceio
# Processing Record 30 of Set 6 | liezen
# Processing Record 31 of Set 6 | bairiki
# Processing Record 32 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 6 | bethel
# Processing Record 34 of Set 6 | cidreira
# Processing Record 35 of Set 6 | eenhana
# Processing Record 36 of Set 6 | liseleje
# Processing Record 37 of Set 6 | oriximina
# Processing Record 38 of Set 6 | yurimaguas
# Processing Record 39 of Set 6 | kodinsk
# Processing Record 40 of Set 6 | mount isa
# Processing Record 41 of Set 6 | simpang
# Processing Record 42 of Set 6 | pinawa
# Processing Record 43 of Set 6 | bonthe
# Processing Record 44 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 45 of Set 6 | cherskiy
# Processing Record 46 of Set 6 | voyvozh
# Processing Record 47 of Set 6 | salinas
# Processing Record 48 of Set 6 | kamenka
# Processing Record 49 of Set 6 | maningrida
# Processing Record 50 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 1 of Set 7 | guider
# Processing Record 2 of Set 7 | tocache
# Processing Record 3 of Set 7 | abong mbang
# Processing Record 4 of Set 7 | zhukovka
# Processing Record 5 of Set 7 | leningradskiy
# Processing Record 6 of Set 7 | aswan
# Processing Record 7 of Set 7 | gurgan
# City not found. Skipping...
# Processing Record 8 of Set 7 | betsiamites
# Processing Record 9 of Set 7 | codrington
# Processing Record 10 of Set 7 | haines junction
# Processing Record 11 of Set 7 | garden city
# Processing Record 12 of Set 7 | bathsheba
# Processing Record 13 of Set 7 | sigli
# Processing Record 14 of Set 7 | pangnirtung
# Processing Record 15 of Set 7 | skhisma
# Processing Record 16 of Set 7 | zaysan
# Processing Record 17 of Set 7 | kununurra
# Processing Record 18 of Set 7 | kovdor
# Processing Record 19 of Set 7 | rafsanjan
# Processing Record 20 of Set 7 | xixiang
# Processing Record 21 of Set 7 | chimore
# Processing Record 22 of Set 7 | bang saphan
# Processing Record 23 of Set 7 | karpathos
# Processing Record 24 of Set 7 | lorengau
# Processing Record 25 of Set 7 | chifeng
# Processing Record 26 of Set 7 | champoton
# Processing Record 27 of Set 7 | jinxiang
# Processing Record 28 of Set 7 | oranjemund
# Processing Record 29 of Set 7 | ballina
# Processing Record 30 of Set 7 | ochamchira
# Processing Record 31 of Set 7 | lethem
# Processing Record 32 of Set 7 | lodwar
# Processing Record 33 of Set 7 | khash
# Processing Record 34 of Set 7 | boguchany
# Processing Record 35 of Set 7 | amahai
# Processing Record 36 of Set 7 | iqaluit
# Processing Record 37 of Set 7 | noumea
# Processing Record 38 of Set 7 | avera
# Processing Record 39 of Set 7 | togur
# Processing Record 40 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 7 | constitucion
# Processing Record 42 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 43 of Set 7 | demba
# Processing Record 44 of Set 7 | hengyang
# Processing Record 45 of Set 7 | kenai
# Processing Record 46 of Set 7 | mogadishu
# Processing Record 47 of Set 7 | tubuala
# Processing Record 48 of Set 7 | mapiripan
# Processing Record 49 of Set 7 | pitimbu
# Processing Record 50 of Set 7 | kaitangata
# Processing Record 1 of Set 8 | mapimi
# Processing Record 2 of Set 8 | port keats
# Processing Record 3 of Set 8 | urusha
# Processing Record 4 of Set 8 | port hardy
# Processing Record 5 of Set 8 | maxixe
# Processing Record 6 of Set 8 | kovur
# Processing Record 7 of Set 8 | metehara
# City not found. Skipping...
# Processing Record 8 of Set 8 | inongo
# Processing Record 9 of Set 8 | hualmay
# Processing Record 10 of Set 8 | siguiri
# Processing Record 11 of Set 8 | chichihualco
# Processing Record 12 of Set 8 | amos
# Processing Record 13 of Set 8 | vao
# Processing Record 14 of Set 8 | novikovo
# Processing Record 15 of Set 8 | killybegs
# Processing Record 16 of Set 8 | ponta do sol
# Processing Record 17 of Set 8 | tilichiki
# Processing Record 18 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 20 of Set 8 | palauig
# Processing Record 21 of Set 8 | cockburn town
# Processing Record 22 of Set 8 | forssa
# Processing Record 23 of Set 8 | zhangye
# Processing Record 24 of Set 8 | ilo
# Processing Record 25 of Set 8 | salalah
# Processing Record 26 of Set 8 | nouadhibou
# Processing Record 27 of Set 8 | roma
# Processing Record 28 of Set 8 | sault sainte marie
# Processing Record 29 of Set 8 | preobrazheniye
# Processing Record 30 of Set 8 | jijiga
# Processing Record 31 of Set 8 | pokhara
# Processing Record 32 of Set 8 | tadine
# Processing Record 33 of Set 8 | half moon bay
# Processing Record 34 of Set 8 | karratha
# Processing Record 35 of Set 8 | peace river
# Processing Record 36 of Set 8 | locri
# Processing Record 37 of Set 8 | minuri
# Processing Record 38 of Set 8 | kamaishi
# Processing Record 39 of Set 8 | khatanga
# Processing Record 40 of Set 8 | synya
# Processing Record 41 of Set 8 | la grande
# Processing Record 42 of Set 8 | laguna
# Processing Record 43 of Set 8 | lages
# Processing Record 44 of Set 8 | boulder
# Processing Record 45 of Set 8 | rensvik
# Processing Record 46 of Set 8 | kaka
# Processing Record 47 of Set 8 | champerico
# Processing Record 48 of Set 8 | mangrol
# Processing Record 49 of Set 8 | monrovia
# Processing Record 50 of Set 8 | kifri
# Processing Record 1 of Set 9 | vercelli
# Processing Record 2 of Set 9 | taltal
# Processing Record 3 of Set 9 | surin
# Processing Record 4 of Set 9 | lavrentiya
# Processing Record 5 of Set 9 | sisimiut
# Processing Record 6 of Set 9 | fairbanks
# Processing Record 7 of Set 9 | khorinsk
# Processing Record 8 of Set 9 | voh
# Processing Record 9 of Set 9 | dukat
# Processing Record 10 of Set 9 | lazaro cardenas
# Processing Record 11 of Set 9 | semnan
# Processing Record 12 of Set 9 | bonavista
# Processing Record 13 of Set 9 | camopi
# Processing Record 14 of Set 9 | quatre cocos
# Processing Record 15 of Set 9 | chukhloma
# Processing Record 16 of Set 9 | hirna
# Processing Record 17 of Set 9 | whitehorse
# Processing Record 18 of Set 9 | merrill
# Processing Record 19 of Set 9 | darovskoy
# Processing Record 20 of Set 9 | coihaique
# Processing Record 21 of Set 9 | solnechnyy
# Processing Record 22 of Set 9 | ximei
# Processing Record 23 of Set 9 | qandahar
# City not found. Skipping...
# Processing Record 24 of Set 9 | timra
# Processing Record 25 of Set 9 | stabroek
# Processing Record 26 of Set 9 | vredendal
# Processing Record 27 of Set 9 | rundu
# Processing Record 28 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 29 of Set 9 | kumluca
# Processing Record 30 of Set 9 | yatou
# Processing Record 31 of Set 9 | dryden
# Processing Record 32 of Set 9 | umm lajj
# Processing Record 33 of Set 9 | cacu
# Processing Record 34 of Set 9 | grand gaube
# Processing Record 35 of Set 9 | bara
# Processing Record 36 of Set 9 | samarai
# Processing Record 37 of Set 9 | xining
# Processing Record 38 of Set 9 | gold coast
# Processing Record 39 of Set 9 | bethlehem
# Processing Record 40 of Set 9 | karkal
# Processing Record 41 of Set 9 | yacuiba
# Processing Record 42 of Set 9 | madimba
# Processing Record 43 of Set 9 | waipawa
# Processing Record 44 of Set 9 | gao
# Processing Record 45 of Set 9 | udachnyy
# Processing Record 46 of Set 9 | zyryanovskiy
# City not found. Skipping...
# Processing Record 47 of Set 9 | vila franca do campo
# Processing Record 48 of Set 9 | uruzgan
# Processing Record 49 of Set 9 | opuwo
# Processing Record 50 of Set 9 | atambua
# Processing Record 1 of Set 10 | hasaki
# Processing Record 2 of Set 10 | praia
# Processing Record 3 of Set 10 | broome
# Processing Record 4 of Set 10 | kupino
# Processing Record 5 of Set 10 | ketchikan
# Processing Record 6 of Set 10 | moba
# Processing Record 7 of Set 10 | yei
# Processing Record 8 of Set 10 | lima
# Processing Record 9 of Set 10 | port blair
# Processing Record 10 of Set 10 | rognan
# Processing Record 11 of Set 10 | ngunguru
# Processing Record 12 of Set 10 | bulaevo
# Processing Record 13 of Set 10 | vardo
# Processing Record 14 of Set 10 | ferrol
# Processing Record 15 of Set 10 | youkounkoun
# Processing Record 16 of Set 10 | marsh harbour
# Processing Record 17 of Set 10 | cody
# Processing Record 18 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 19 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 20 of Set 10 | la ronge
# Processing Record 21 of Set 10 | niamey
# Processing Record 22 of Set 10 | sabha
# Processing Record 23 of Set 10 | bela vista
# Processing Record 24 of Set 10 | husavik
# Processing Record 25 of Set 10 | nelson bay
# Processing Record 26 of Set 10 | arcata
# Processing Record 27 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 28 of Set 10 | eidfjord
# Processing Record 29 of Set 10 | lawton
# Processing Record 30 of Set 10 | evinayong
# Processing Record 31 of Set 10 | axim
# Processing Record 32 of Set 10 | porto velho
# Processing Record 33 of Set 10 | tepeojuma
# Processing Record 34 of Set 10 | koumac
# Processing Record 35 of Set 10 | sobolevo
# Processing Record 36 of Set 10 | mount gambier
# Processing Record 37 of Set 10 | ahar
# Processing Record 38 of Set 10 | bria
# Processing Record 39 of Set 10 | karaton
# Processing Record 40 of Set 10 | hay river
# Processing Record 41 of Set 10 | buala
# Processing Record 42 of Set 10 | malindi
# Processing Record 43 of Set 10 | buta
# Processing Record 44 of Set 10 | talcahuano
# Processing Record 45 of Set 10 | itupiranga
# Processing Record 46 of Set 10 | deputatskiy
# Processing Record 47 of Set 10 | saint-augustin
# Processing Record 48 of Set 10 | copiapo
# Processing Record 49 of Set 10 | flinders
# Processing Record 50 of Set 10 | donskoye
# Processing Record 1 of Set 11 | warmbad
# Processing Record 2 of Set 11 | morgan city
# Processing Record 3 of Set 11 | mullaitivu
# City not found. Skipping...
# Processing Record 4 of Set 11 | kaeo
# Processing Record 5 of Set 11 | fuyu
# Processing Record 6 of Set 11 | huntsville
# Processing Record 7 of Set 11 | pochutla
# Processing Record 8 of Set 11 | namtsy
# Processing Record 9 of Set 11 | basti
# Processing Record 10 of Set 11 | walvis bay
# Processing Record 11 of Set 11 | kulhudhuffushi
# Processing Record 12 of Set 11 | westport
# Processing Record 13 of Set 11 | ishurdi
# Processing Record 14 of Set 11 | ixtapa
# Processing Record 15 of Set 11 | lasa
# Processing Record 16 of Set 11 | palu
# Processing Record 17 of Set 11 | staryy nadym
# Processing Record 18 of Set 11 | najran
# Processing Record 19 of Set 11 | zeya
# Processing Record 20 of Set 11 | snezhnogorsk
# Processing Record 21 of Set 11 | taikang
# Processing Record 22 of Set 11 | enying
# Processing Record 23 of Set 11 | ellisras
# Processing Record 24 of Set 11 | burnie
# Processing Record 25 of Set 11 | xichang
# Processing Record 26 of Set 11 | zhigansk
# Processing Record 27 of Set 11 | labuhan
# Processing Record 28 of Set 11 | havoysund
# Processing Record 29 of Set 11 | sola
# Processing Record 30 of Set 11 | bari sadri
# Processing Record 31 of Set 11 | chicama
# Processing Record 32 of Set 11 | mirabad
# Processing Record 33 of Set 11 | sovetskiy
# Processing Record 34 of Set 11 | san cristobal
# Processing Record 35 of Set 11 | santa maria
# Processing Record 36 of Set 11 | urumqi
# Processing Record 37 of Set 11 | kathmandu
# Processing Record 38 of Set 11 | matara
# Processing Record 39 of Set 11 | santiago
# Processing Record 40 of Set 11 | sinop
# Processing Record 41 of Set 11 | caraquet
# Processing Record 42 of Set 11 | chardara
# Processing Record 43 of Set 11 | sao joao da barra
# Processing Record 44 of Set 11 | chiang rai
# Processing Record 45 of Set 11 | tome-acu
# City not found. Skipping...
# Processing Record 46 of Set 11 | balaipungut
# Processing Record 47 of Set 11 | manama
# Processing Record 48 of Set 11 | shrigonda
# Processing Record 49 of Set 11 | barpeta
# Processing Record 50 of Set 11 | shakiso

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE

# Display sample data
# YOUR CODE HERE

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# YOUR CODE HERE

# Export the city_data DataFrame into a CSV file
# YOUR CODE HERE
